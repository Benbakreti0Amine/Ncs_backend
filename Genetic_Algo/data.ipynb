# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def scrape_geonames_page(start_row):
    url = "https://www.geonames.org/search.html"
    params = {
        "q": "algiers",
        "startRow": start_row
    }

    print(f"Scraping startRow={start_row} ...")
    response = requests.get(url, params=params)
    soup = BeautifulSoup(response.content, "html.parser")
    table = soup.find("table", class_="restable")
    rows = table.find_all("tr")[1:]  # skip header

    places = []
    for row in rows:
        cols = row.find_all("td")
        if len(cols) < 6:
            continue
        name = cols[0].text.strip()
        country = cols[1].text.strip()
        feature_class = cols[2].text.strip()
        population = cols[3].text.strip().replace(",", "")
        latitude = cols[4].text.strip()
        longitude = cols[5].text.strip()

        places.append({
            "Name": name,
            "Country": country,
            "Feature Class": feature_class,
            "Population": population,
            "Latitude": latitude,
            "Longitude": longitude
        })

    return places

# Collect data from 4 pages
all_places = []
for start in [0, 50, 100, 150]:
    all_places.extend(scrape_geonames_page(start))
    time.sleep(1)  # be polite to the server

# Save to CSV
df = pd.DataFrame(all_places)
df.to_csv("geonames_algiers_0_150.csv", index=False)
print("Saved to geonames_algiers_0_150.csv")
# Out:
# Scraping startRow=0 ...
# Scraping startRow=50 ...
# Scraping startRow=100 ...
# Scraping startRow=150 ...
# Saved to geonames_algiers_0_150.csv

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.citypopulation.de/en/algeria/admin/16__el_djaza%C3%AFr/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

table = soup.find("table", class_="data")
rows = table.find_all("tr")[1:]  # skip header

data = []
for row in rows:
    cols = row.find_all("td")
    if len(cols) >= 5:
        name = cols[0].text.strip()
        status = cols[1].text.strip()
        pop_1998 = cols[2].text.strip().replace(",", "")
        pop_2008 = cols[3].text.strip().replace(",", "")
        native = cols[4].text.strip()

        # Only add rows where population values are valid numbers
        if pop_1998.isdigit() and pop_2008.isdigit():
            data.append({
                "Commune": name,
                "Status": status,
                "Population 1998": int(pop_1998),
                "Population 2008": int(pop_2008),
                "Native": native
            })

# Save to CSV
df = pd.DataFrame(data)
df.to_csv("algiers_population_by_commune.csv", index=False)
print("Saved to algiers_population_by_commune.csv")
# Out:
# Saved to algiers_population_by_commune.csv

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

def scrape_algiers_population():
    """
    Scrape population data for Algiers communes from citypopulation.de
    """
    url = "https://www.citypopulation.de/en/algeria/admin/16__el_djaza%C3%AFr/"
    
    print("Fetching data from citypopulation.de...")
    
    # Send GET request with headers to avoid blocking
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        # Parse HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all tables with class 'data'
        tables = soup.find_all('table', {'class': 'data'})
        
        if not tables:
            print("Could not find any data tables on the page")
            return None
        
        # The main table with commune data is usually the largest one
        # Let's find all rows across all tables
        all_data = []
        
        for table in tables:
            # Find all rows in the table
            rows = table.find_all('tr')
            print(f"Found {len(rows)} rows in a table")
            
            # Skip header rows - we'll process each row and check if it has commune data
            for row in rows:
                # Check if this is a data row (not a header)
                cells = row.find_all(['td', 'th'])
                
                if len(cells) >= 5:  # We need at least 5 columns (name, status, native, pop1998, pop2008)
                    # Skip if this is a header row
                    if row.find('th'):
                        continue
                    
                    # Extract place name (first cell)
                    name_cell = cells[0]
                    
                    # Skip the province row (we want communes)
                    cell_text = name_cell.get_text().strip()
                    if "Province" in str(row):
                        continue
                        
                    # Get place name
                    place_name = None
                    name_link = name_cell.find('a')
                    if name_link:
                        place_name = name_link.get_text().strip()
                    else:
                        place_name = cell_text
                    
                    # Skip empty rows or header rows
                    if not place_name or place_name == "Name":
                        continue
                    
                    # Extract status (usually "Commune")
                    status = ""
                    if len(cells) > 1:
                        status = cells[1].get_text().strip()
                    
                    # Extract native name
                    native_name = ""
                    if len(cells) > 2:
                        native_name = cells[2].get_text().strip()
                    
                    # Extract population data
                    population_1998 = None
                    population_2008 = None
                    
                    # Population 1998 (usually 4th column)
                    if len(cells) > 3:
                        pop_text = cells[3].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_1998 = int(clean_number)
                    
                    # Population 2008 (usually 5th column)
                    if len(cells) > 4:
                        pop_text = cells[4].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_2008 = int(clean_number)
                    
                    # Add to our data list
                    all_data.append({
                        'place_name': place_name,
                        'status': status,
                        'native_name': native_name,
                        'population_1998': population_1998,
                        'population_2008': population_2008
                    })
        
        print(f"Successfully extracted data for {len(all_data)} places")
        
        # Create DataFrame
        df = pd.DataFrame(all_data)
        
        # Save to CSV
        csv_filename = 'algiers_population_data.csv'
        df.to_csv(csv_filename, index=False, encoding='utf-8')
        
        print(f"Data saved to {csv_filename}")
        print("\nFirst few rows of the dataset:")
        print(df.head(10))
        
        print(f"\nDataset summary:")
        print(f"Total places: {len(df)}")
        print(f"Places with 1998 data: {df['population_1998'].notna().sum()}")
        print(f"Places with 2008 data: {df['population_2008'].notna().sum()}")
        
        return df
        
    except requests.RequestException as e:
        print(f"Error fetching the webpage: {e}")
        return None
    except Exception as e:
        print(f"Error processing data: {e}")
        import traceback
        traceback.print_exc()
        return None

# Run the scraper
if __name__ == "__main__":
    df = scrape_algiers_population()
    
    if df is not None:
        print("\n" + "="*50)
        print("SCRAPING COMPLETED SUCCESSFULLY!")
        print("="*50)
        print(f"CSV file 'algiers_population_data.csv' has been created with {len(df)} records")
    else:
        print("Scraping failed. Please check the error messages above.")
# Out:
# Fetching data from citypopulation.de...
# Found 60 rows in a table
# Found 3 rows in a table
# Found 4 rows in a table
# Found 10 rows in a table
# Found 4 rows in a table
# Successfully extracted data for 58 places
# Data saved to algiers_population_data.csv
#
# First few rows of the dataset:
#      place_name   status  native_name  population_1998  population_2008
# 0    Aïn Benian  Commune  عين البنيان            52343            68354
# 1      Aïn Taya  Commune     عين طاية            29515            34501
# 2   Baba Hassen  Commune     بابا حسن            13827            23756
# 3   Bab El Oued  Commune   باب الوادي            87557            64732
# 4   Bab Ezzouar  Commune   باب الزوار            92157            96597
# 5   Bachdjerrah  Commune     باش جراح            90073            93289
# 6        Baraki  Commune        براقي            95247           116375
# 7    Ben Aknoun  Commune     بن عكنون            19404            18838
# 8  Beni Messous  Commune     بني مسوس            17490            36191
# 9     Birkhadem  Commune     بئر خادم            55084            77749
#
# Dataset summary:
# Total places: 58
# Places with 1998 data: 58
# Places with 2008 data: 58
#
# ==================================================
# SCRAPING COMPLETED SUCCESSFULLY!
# ==================================================
# CSV file 'algiers_population_data.csv' has been created with 58 records

# %%
import pandas as pd
from fuzzywuzzy import fuzz, process
import re

def clean_place_name(name):
    """
    Clean and normalize place names for better matching
    """
    if pd.isna(name):
        return ""
    
    # Convert to string and strip whitespace
    name = str(name).strip()
    
    # Remove common prefixes/suffixes that might cause mismatches
    name = re.sub(r'\s*\[.*?\]\s*', '', name)  # Remove [Algiers] type suffixes
    name = re.sub(r'\s*$$.*?$$\s*', '', name)  # Remove (parentheses)
    
    # Normalize common variations
    name = name.replace('El ', '').replace('Al ', '').replace('el ', '').replace('al ', '')
    name = name.replace('-', ' ').replace('_', ' ')
    
    # Remove extra whitespace
    name = ' '.join(name.split())
    
    return name.lower()

def convert_dms_to_decimal(dms_str):
    """
    Convert degrees/minutes/seconds format to decimal degrees
    Example: "N 36° 43′ 56''" -> 36.732222
    """
    if pd.isna(dms_str) or not isinstance(dms_str, str):
        return None
    
    # Extract direction (N/S/E/W)
    direction = 1
    if 'S' in dms_str or 'W' in dms_str:
        direction = -1
    
    # Extract numbers using regex
    numbers = re.findall(r'\d+', dms_str)
    
    if len(numbers) >= 2:
        degrees = float(numbers[0])
        minutes = float(numbers[1])
        seconds = float(numbers[2]) if len(numbers) > 2 else 0
        
        decimal = degrees + minutes/60 + seconds/3600
        return decimal * direction
    
    return None

def extract_place_names(name_field):
    """
    Extract all possible place names from the complex name field
    """
    if pd.isna(name_field):
        return []
    
    name_str = str(name_field)
    names = []
    
    # Split by common separators
    parts = re.split(r'[,;|]', name_str)
    
    for part in parts:
        # Clean each part
        clean_part = part.strip()
        
        # Remove coordinates if embedded
        clean_part = re.sub(r'\d+\.\d+', '', clean_part)
        
        # Remove extra whitespace
        clean_part = ' '.join(clean_part.split())
        
        if clean_part and len(clean_part) > 2:
            names.append(clean_part)
    
    return names

def normalize_name(name):
    """
    Normalize place names for better matching
    """
    if pd.isna(name) or not name:
        return ""
    
    name = str(name).strip().lower()
    
    # Remove common prefixes and suffixes
    name = re.sub(r'\s*\[.*?\]\s*', '', name)
    name = re.sub(r'\s*$$.*?$$\s*', '', name)
    
    # Normalize common Arabic transliterations
    replacements = {
        'aïn': 'ain', 'aín': 'ain', 'aîn': 'ain',
        'bab': 'bab', 'baab': 'bab',
        'el ': '', 'al ': '', 'ed ': '', 'ad ': '',
        'dj': 'j', 'dz': 'z',
        'ou': 'u', 'oo': 'u',
        'kh': 'h', 'gh': 'g',
        'ï': 'i', 'î': 'i', 'í': 'i',
        'é': 'e', 'è': 'e', 'ê': 'e',
        'ç': 'c', 'ş': 's', 'ğ': 'g'
    }
    
    for old, new in replacements.items():
        name = name.replace(old, new)
    
    # Remove extra spaces and special characters
    name = re.sub(r'[^\w\s]', ' ', name)
    name = ' '.join(name.split())
    
    return name

def smart_match(pop_name, geo_names_list, threshold=60):
    """
    Smart matching using multiple strategies
    """
    if not pop_name or not geo_names_list:
        return None, 0
    
    normalized_pop = normalize_name(pop_name)
    best_match = None
    best_score = 0
    best_original = None
    
    for geo_entry in geo_names_list:
        geo_names = extract_place_names(geo_entry)
        
        for geo_name in geo_names:
            normalized_geo = normalize_name(geo_name)
            
            # Strategy 1: Exact match after normalization
            if normalized_pop == normalized_geo:
                return geo_entry, 100
            
            # Strategy 2: One name contains the other
            if normalized_pop in normalized_geo or normalized_geo in normalized_pop:
                score = 90
                if score > best_score:
                    best_score = score
                    best_match = geo_entry
                    best_original = geo_name
            
            # Strategy 3: Fuzzy matching
            ratio_score = fuzz.ratio(normalized_pop, normalized_geo)
            partial_score = fuzz.partial_ratio(normalized_pop, normalized_geo)
            token_score = fuzz.token_sort_ratio(normalized_pop, normalized_geo)
            
            # Use the highest score
            max_score = max(ratio_score, partial_score, token_score)
            
            if max_score > best_score and max_score >= threshold:
                best_score = max_score
                best_match = geo_entry
                best_original = geo_name
    
    return best_match, best_score

def merge_algiers_datasets():
    """
    Merge population data with geographic coordinates using smart matching
    """
    print("Loading datasets...")
    
    try:
        # Load population data
        pop_df = pd.read_csv('algiers_population_data.csv')
        print(f"Loaded population data: {len(pop_df)} records")
        print("Population data columns:", pop_df.columns.tolist())
        print("Sample population data:")
        print(pop_df.head())
        
        # Load geographic data
        geo_df = pd.read_csv('geonames_algiers_0_150.csv')
        print(f"\nLoaded geographic data: {len(geo_df)} records")
        print("Geographic data columns:", geo_df.columns.tolist())
        print("Sample geographic data:")
        print(geo_df.head())
        
    except FileNotFoundError as e:
        print(f"Error: Could not find file - {e}")
        print("Make sure both CSV files are in the same directory as this script")
        return None
    
    # Process geographic data to extract coordinates
    print("\nProcessing geographic coordinates...")
    
    processed_geo_data = []
    
    for idx, row in geo_df.iterrows():
        # Extract coordinates from Latitude and Longitude columns
        lat_decimal = convert_dms_to_decimal(row['Latitude'])
        lon_decimal = convert_dms_to_decimal(row['Longitude'])
        
        if lat_decimal is not None and lon_decimal is not None:
            processed_geo_data.append({
                'original_name': row['Name'],
                'latitude': lat_decimal,
                'longitude': lon_decimal,
                'all_names': extract_place_names(row['Name'])
            })
    
    print(f"Successfully processed {len(processed_geo_data)} geographic records with valid coordinates")
    
    # Show some examples of processed data
    print("\nSample processed geographic data:")
    for i, item in enumerate(processed_geo_data[:5]):
        print(f"{i+1}. Names: {item['all_names'][:3]}... -> Lat: {item['latitude']:.4f}, Lon: {item['longitude']:.4f}")
    
    # Prepare list of all geographic names for matching
    geo_names_list = [item['original_name'] for item in processed_geo_data]
    
    # Match population data with geographic data
    print(f"\nStarting smart matching process...")
    merged_data = []
    
    for idx, pop_row in pop_df.iterrows():
        place_name = pop_row['place_name']
        population_2008 = pop_row['population_2008']
        
        # Skip if no 2008 population data
        if pd.isna(population_2008):
            print(f"⚠ Skipping '{place_name}' - no 2008 population data")
            continue
        
        # Find best matching geographic location
        best_match, score = smart_match(place_name, geo_names_list)
        
        if best_match and score >= 60:
            # Find the corresponding processed geo data
            geo_item = next((item for item in processed_geo_data if item['original_name'] == best_match), None)
            
            if geo_item:
                merged_data.append({
                    'place_name': place_name,
                    'longitude': geo_item['longitude'],
                    'latitude': geo_item['latitude'],
                    'population_2008': int(population_2008),
                    'match_score': score,
                    'matched_with': best_match
                })
                
                print(f"✓ Matched '{place_name}' with '{best_match}' (score: {score})")
            else:
                print(f"✗ Found match but couldn't locate geo data for '{place_name}'")
        else:
            print(f"✗ No good match found for '{place_name}' (best score: {score})")
    
    if not merged_data:
        print("No matches found between datasets!")
        return None
    
    # Create final DataFrame
    final_df = pd.DataFrame(merged_data)
    
    # Sort by population (descending)
    final_df = final_df.sort_values('population_2008', ascending=False)
    
    # Create the final dataset with only requested columns
    result_df = final_df[['place_name', 'longitude', 'latitude', 'population_2008']].copy()
    
    # Save to CSV
    output_filename = 'algiers_combined_dataset.csv'
    result_df.to_csv(output_filename, index=False)
    
    print(f"\n" + "="*60)
    print("DATASET MERGING COMPLETED!")
    print("="*60)
    print(f"Successfully merged {len(result_df)} places")
    print(f"Output saved to: {output_filename}")
    
    print(f"\nFinal dataset preview:")
    print(result_df.head(10))
    
    print(f"\nDataset statistics:")
    print(f"Total places: {len(result_df)}")
    print(f"Average population: {result_df['population_2008'].mean():.0f}")
    if len(result_df) > 0:
        print(f"Largest city: {result_df.iloc[0]['place_name']} ({result_df.iloc[0]['population_2008']:,})")
        print(f"Smallest city: {result_df.iloc[-1]['place_name']} ({result_df.iloc[-1]['population_2008']:,})")
    
    # Show matching details
    print(f"\nMatching details:")
    match_details = final_df[['place_name', 'matched_with', 'match_score']].head(10)
    print(match_details)
    
    return result_df

# Run the merger
if __name__ == "__main__":
    result = merge_algiers_datasets()
    
    if result is not None:
        print(f"\n🎉 Success! Combined dataset created with {len(result)} records")
        print("File: algiers_combined_dataset.csv")
    else:
        print("❌ Failed to create combined dataset")
# Out:
# Loading datasets...
# Loaded population data: 58 records
# Population data columns: ['place_name', 'status', 'native_name', 'population_1998', 'population_2008']
# Sample population data:
#         place_name   status  native_name  population_1998  population_2008
# 0       Aïn Benian  Commune  عين البنيان            52343            68354
# 1         Aïn Taya  Commune     عين طاية            29515            34501
# 2      Baba Hassen  Commune     بابا حسن            13827            23756
# 3      Bab El Oued  Commune   باب الوادي            87557            64732
# 4      Bab Ezzouar  Commune   باب الزوار            92157            96597
#
# Loaded geographic data: 200 records
# Geographic data columns: ['Name', 'Country', 'Feature Class', 'Population', 'Latitude', 'Longitude']
# Sample geographic data:
#    Name                                            Country  \
# 0     1  Algiers  ALG,Al Jazair,Al-jezair,Alcher,Alge,A...
# 1     2  Bab Ezzouar  Bab Ezzouar,Le Retour de la Chass...
# 2     3  Algiers Airport  ALG,Aeroport d'Alger Houari B...
# 3     4  Algiers  Alger,Algier,Algiers,Algiers Province...
# 4     5    Rouiba  Rouiba,alrwybt,الرويبة36.7382913.280787
#
#                                        Feature Class  \
# 0                                   Algeria, Algiers
# 1  Algeria, AlgiersDaïra de Dar el Beïda > Bab Ez...
# 2  Algeria, AlgiersDaïra de Dar el Beïda > Commun...
# 3                                   Algeria, Algiers
# 4         Algeria, AlgiersRouiba > Commune de Rouiba
#
#                                           Population        Latitude  \
# 0    capital of a political entitypopulation 2364230  N 36° 43′ 56''
# 1                   populated placepopulation 275630  N 36° 43′ 34''
# 2                               airportelevation 24m  N 36° 41′ 54''
# 3  first-order administrative divisionpopulation ...  N 36° 44′ 25''
# 4                   populated placepopulation 117558  N 36° 44′ 17''
#
#        Longitude
# 0   E 3° 5′ 14''
# 1  E 3° 10′ 58''
# 2  E 3° 12′ 24''
# 3   E 3° 0′ 34''
# 4  E 3° 16′ 50''
#
# Processing geographic coordinates...
# Successfully processed 200 geographic records with valid coordinates
#
# Sample processed geographic data:
# 1. Names: []... -> Lat: 36.7322, Lon: 3.0872
# 2. Names: []... -> Lat: 36.7261, Lon: 3.1828
# 3. Names: []... -> Lat: 36.6983, Lon: 3.2067
# 4. Names: []... -> Lat: 36.7403, Lon: 3.0094
# 5. Names: []... -> Lat: 36.7381, Lon: 3.2806
#
# Starting smart matching process...
# ✗ No good match found for 'Aïn Benian' (best score: 0)
# ✗ No good match found for 'Aïn Taya' (best score: 0)
# ✗ No good match found for 'Baba Hassen' (best score: 0)
# ✗ No good match found for 'Bab El Oued' (best score: 0)
# ✗ No good match found for '    Bab Ezzouar' (best score: 0)
# ✗ No good match found for 'Bachdjerrah' (best score: 0)
# ✗ No good match found for 'Baraki' (best score: 0)
# ✗ No good match found for 'Ben Aknoun' (best score: 0)
# ✗ No good match found for 'Beni Messous' (best score: 0)
# ✗ No good match found for 'Birkhadem' (best score: 0)
# ✗ No good match found for 'Bir Mourad Raïs' (best score: 0)
# ✗ No good match found for 'Birtouta' (best score: 0)
# ✗ No good match found for 'Bologhine' (best score: 0)
# ✗ No good match found for 'Bordj El Bahri' (best score: 0)
# ✗ No good match found for 'Bordj El Kiffan' (best score: 0)
# ✗ No good match found for 'Bourouba' (best score: 0)
# ✗ No good match found for 'Bouzereah' (best score: 0)
# ✗ No good match found for 'Casbah' (best score: 0)
# ✗ No good match found for 'Chéraga' (best score: 0)
# ✗ No good match found for 'Dar El Beïda' (best score: 0)
# ✗ No good match found for 'Dely Ibrahim' (best score: 0)
# ✗ No good match found for 'Djasr Kasentina' (best score: 0)
# ✗ No good match found for 'Douera' (best score: 0)
# ✗ No good match found for 'Draria' (best score: 0)
# ✗ No good match found for 'El Achour' (best score: 0)
# ✗ No good match found for 'El Biar' (best score: 0)
# ✗ No good match found for 'El Djazaïr' (best score: 0)
# ✗ No good match found for 'El Hammamet' (best score: 0)
# ✗ No good match found for 'El Harrach' (best score: 0)
# ✗ No good match found for 'El Madania' (best score: 0)
# ✗ No good match found for 'El Magharia' (best score: 0)
# ✗ No good match found for 'El Marsa' (best score: 0)
# ✗ No good match found for 'El Mouradia' (best score: 0)
# ✗ No good match found for 'Harraoua' (best score: 0)
# ✗ No good match found for 'Hussein Dey' (best score: 0)
# ✗ No good match found for 'Hydra' (best score: 0)
# ✗ No good match found for 'Khraicia' (best score: 0)
# ✗ No good match found for 'Kouba' (best score: 0)
# ✗ No good match found for 'Les Eucalyptus' (best score: 0)
# ✗ No good match found for 'Mahelma' (best score: 0)
# ✗ No good match found for 'Mohamed Belouizdad (Hamma Annassers)' (best score: 0)
# ✗ No good match found for 'Mohammadia' (best score: 0)
# ✗ No good match found for 'Oued Koriche' (best score: 0)
# ✗ No good match found for 'Oued Smar' (best score: 0)
# ✗ No good match found for 'Ouled Chebel' (best score: 0)
# ✗ No good match found for 'Ouled Fayet' (best score: 0)
# ✗ No good match found for 'Rahmania' (best score: 0)
# ✗ No good match found for 'Raïs Hamidou' (best score: 0)
# ✗ No good match found for 'Reghaïa' (best score: 0)
# ✗ No good match found for 'Rouïba' (best score: 0)
# ✗ No good match found for 'Saoula' (best score: 0)
# ✗ No good match found for 'Sidi M'Hamed' (best score: 0)
# ✗ No good match found for 'Sidi Moussa' (best score: 0)
# ✗ No good match found for 'Souidania' (best score: 0)
# ✗ No good match found for 'Staoueli' (best score: 0)
# ✗ No good match found for 'Tessala El Merdja' (best score: 0)
# ✗ No good match found for 'Zéralda' (best score: 0)
# ✗ No good match found for 'Algérie [Algeria]' (best score: 0)
# No matches found between datasets!
# ❌ Failed to create combined dataset

# %%
import pandas as pd
import re

def clean_name(name):
    """Clean name by removing special characters and converting to lowercase"""
    if pd.isna(name):
        return ""
    
    # Convert to string and lowercase
    name = str(name).lower()
    
    # Remove special characters and keep only letters and spaces
    name = re.sub(r'[^a-zA-Z\s]', '', name)
    
    # Remove extra spaces
    name = re.sub(r'\s+', ' ', name).strip()
    
    return name

def has_4_successive_chars(name1, name2):
    """Check if two names share 4 successive characters"""
    if not name1 or not name2:
        return False
    
    name1_clean = clean_name(name1).replace(' ', '')  # Remove spaces for character matching
    name2_clean = clean_name(name2).replace(' ', '')
    
    # Check all 4-character substrings in name1
    for i in range(len(name1_clean) - 3):
        substring = name1_clean[i:i+4]
        if substring in name2_clean:
            print(f"  Found matching substring '{substring}' in '{name1}' and '{name2}'")
            return True
    
    return False

def extract_population(pop_str):
    """Extract population numbers from string"""
    if pd.isna(pop_str):
        return None
    
    try:
        # Remove asterisks and convert to int
        pop_str = str(pop_str).replace('*', '').replace(',', '')
        return int(pop_str) if pop_str.isdigit() else None
    except:
        return None

def parse_coordinates(coord_str):
    """Parse coordinate strings to decimal degrees"""
    if pd.isna(coord_str):
        return None
    
    try:
        coord_str = str(coord_str).strip()
        
        # Check if already decimal
        if '°' not in coord_str:
            return float(coord_str)
        
        # Parse degree format
        direction = 1
        if coord_str.startswith('S') or coord_str.startswith('W'):
            direction = -1
        
        # Extract numbers
        numbers = re.findall(r'\d+(?:\.\d+)?', coord_str)
        
        if len(numbers) >= 1:
            degrees = float(numbers[0])
            minutes = float(numbers[1]) if len(numbers) > 1 else 0
            seconds = float(numbers[2]) if len(numbers) > 2 else 0
            
            decimal = direction * (degrees + minutes/60 + seconds/3600)
            return decimal
    except:
        return None
    
    return None

def load_population_data(filepath):
    """Load and clean population dataset"""
    try:
        df = pd.read_csv(filepath)
        
        # Clean column names
        df.columns = df.columns.str.strip()
        
        # Process population columns
        if '*population_1998' in df.columns:
            df['population_1998'] = df['*population_1998'].apply(extract_population)
        
        if '*population_2008' in df.columns:
            df['population_2008'] = df['*population_2008'].apply(extract_population)
        
        return df
    except Exception as e:
        print(f"Error loading population data: {e}")
        return None

def load_geonames_data(filepath):
    """Load and clean geonames dataset"""
    try:
        df = pd.read_csv(filepath)
        
        # Clean column names
        df.columns = df.columns.str.strip()
        
        # Parse coordinates
        if '*Latitude' in df.columns:
            df['latitude'] = df['*Latitude'].apply(parse_coordinates)
        
        if '*Longitude*' in df.columns:
            df['longitude'] = df['*Longitude*'].apply(parse_coordinates)
        
        # Extract population from geonames
        if '*Population' in df.columns:
            df['geonames_population'] = df['*Population'].apply(extract_population)
        
        # Use the entire Name field for matching (contains all variations)
        df['main_name'] = df['Name'].astype(str)
        
        return df
    except Exception as e:
        print(f"Error loading geonames data: {e}")
        return None

def merge_datasets_simple(pop_filepath, geo_filepath, output_filepath=None):
    """Merge datasets using simple 4-character matching"""
    
    print("Loading population data...")
    pop_df = load_population_data(pop_filepath)
    if pop_df is None:
        return None
    
    print("Loading geonames data...")
    geo_df = load_geonames_data(geo_filepath)
    if geo_df is None:
        return None
    
    print(f"Population dataset: {len(pop_df)} records")
    print(f"Geonames dataset: {len(geo_df)} records")
    
    print("Matching places based on 4 successive characters...")
    
    merged_data = []
    matches_found = 0
    
    # For each place in population dataset
    for pop_idx, pop_row in pop_df.iterrows():
        place_name = pop_row['place_name']
        match_found = False
        
        # Check against all names in geonames dataset
        for geo_idx, geo_row in geo_df.iterrows():
            geo_name = geo_row['main_name']
            
            print(f"Checking: '{place_name}' against '{geo_name[:50]}...'")  # Show first 50 chars
            
            # Check if they share 4 successive characters
            if has_4_successive_chars(place_name, geo_name):
                # Create merged record
                merged_record = {
                    'place_name': place_name,
                    'matched_geoname': geo_name,
                    'status': pop_row.get('status', ''),
                    'native_name': pop_row.get('native_name', ''),
                    'population_1998': pop_row.get('population_1998', None),
                    'population_2008': pop_row.get('population_2008', None),
                    'geonames_population': geo_row.get('geonames_population', None),
                    'latitude': geo_row.get('latitude', None),
                    'longitude': geo_row.get('longitude', None)
                }
                merged_data.append(merged_record)
                match_found = True
                matches_found += 1
                print(f"Match found: '{place_name}' <-> '{geo_name}'")
                break  # Take first match only
        
        # If no match found, add record without coordinates
        if not match_found:
            merged_record = {
                'place_name': place_name,
                'matched_geoname': '',
                'status': pop_row.get('status', ''),
                'native_name': pop_row.get('native_name', ''),
                'population_1998': pop_row.get('population_1998', None),
                'population_2008': pop_row.get('population_2008', None),
                'geonames_population': None,
                'latitude': None,
                'longitude': None
            }
            merged_data.append(merged_record)
    
    # Create final dataframe
    merged_df = pd.DataFrame(merged_data)
    
    print(f"\nMatching complete!")
    print(f"Total records in merged dataset: {len(merged_df)}")
    print(f"Records with matches (coordinates): {matches_found}")
    print(f"Records without matches: {len(merged_df) - matches_found}")
    
    # Save to file if output path provided
    if output_filepath:
        merged_df.to_csv(output_filepath, index=False)
        print(f"Merged dataset saved to: {output_filepath}")
    
    return merged_df

# Usage
if __name__ == "__main__":
    # File paths
    population_file = r"C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\algiers_population_data.csv"
    geonames_file = r"C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\geonames_algiers_0_150.csv"
    output_file = r"C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\merged_algiers_data.csv"
    
    # Merge datasets
    merged_dataset = merge_datasets_simple(
        pop_filepath=population_file,
        geo_filepath=geonames_file,
        output_filepath=output_file
    )
    
    if merged_dataset is not None:
        print("\nSample of merged data:")
        print(merged_dataset[['place_name', 'matched_geoname', 'latitude', 'longitude', 'population_2008']].head(10))
        
        print("\nFinal dataset summary:")
        print(f"Total records: {len(merged_dataset)}")
        print(f"Records with coordinates: {merged_dataset['latitude'].notna().sum()}")
        print(f"Records with 2008 population: {merged_dataset['population_2008'].notna().sum()}")
# Out:
# Loading population data...
# Loading geonames data...
# Population dataset: 58 records
# Geonames dataset: 200 records
# Matching places based on 4 successive characters...
# Checking: 'Aïn Benian' against '1...'
# Checking: 'Aïn Benian' against '2...'
# Checking: 'Aïn Benian' against '3...'
# Checking: 'Aïn Benian' against '4...'
# Checking: 'Aïn Benian' against '5...'
# Checking: 'Aïn Benian' against '6...'
# Checking: 'Aïn Benian' against '7...'
# Checking: 'Aïn Benian' against '8...'
# Checking: 'Aïn Benian' against '9...'
# Checking: 'Aïn Benian' against '10...'
# Checking: 'Aïn Benian' against '11...'
# Checking: 'Aïn Benian' against '12...'
# Checking: 'Aïn Benian' against '13...'
# Checking: 'Aïn Benian' against '14...'
# Checking: 'Aïn Benian' against '15...'
# Checking: 'Aïn Benian' against '16...'
# Checking: 'Aïn Benian' against '17...'
# Checking: 'Aïn Benian' against '18...'
# Checking: 'Aïn Benian' against '19...'
# Checking: 'Aïn Benian' against '20...'
# Checking: 'Aïn Benian' against '21...'
# Checking: 'Aïn Benian' against '22...'
# Checking: 'Aïn Benian' against '23...'
# Checking: 'Aïn Benian' against '24...'
# Checking: 'Aïn Benian' against '25...'
# Checking: 'Aïn Benian' against '26...'
# Checking: 'Aïn Benian' against '27...'
# Checking: 'Aïn Benian' against '28...'
# Checking: 'Aïn Benian' against '29...'
# Checking: 'Aïn Benian' against '30...'
# Checking: 'Aïn Benian' against '31...'
# Checking: 'Aïn Benian' against '32...'
# Checking: 'Aïn Benian' against '33...'
# Checking: 'Aïn Benian' against '34...'
# Checking: 'Aïn Benian' against '35...'
# Checking: 'Aïn Benian' against '36...'
# Checking: 'Aïn Benian' against '37...'
# Checking: 'Aïn Benian' against '38...'
# Checking: 'Aïn Benian' against '39...'
# Checking: 'Aïn Benian' against '40...'
# Checking: 'Aïn Benian' against '41...'
# Checking: 'Aïn Benian' against '42...'
# Checking: 'Aïn Benian' against '43...'
# Checking: 'Aïn Benian' against '44...'
# Checking: 'Aïn Benian' against '45...'
# Checking: 'Aïn Benian' against '46...'
# Checking: 'Aïn Benian' against '47...'
# Checking: 'Aïn Benian' against '48...'
# Checking: 'Aïn Benian' against '49...'
# Checking: 'Aïn Benian' against '50...'
# Checking: 'Aïn Benian' against '51...'
# Checking: 'Aïn Benian' against '52...'
# Checking: 'Aïn Benian' against '53...'
# Checking: 'Aïn Benian' against '54...'
# Checking: 'Aïn Benian' against '55...'
# Checking: 'Aïn Benian' against '56...'
# Checking: 'Aïn Benian' against '57...'
# Checking: 'Aïn Benian' against '58...'
# Checking: 'Aïn Benian' against '59...'
# Checking: 'Aïn Benian' against '60...'
# Checking: 'Aïn Benian' against '61...'
# Checking: 'Aïn Benian' against '62...'
# Checking: 'Aïn Benian' against '63...'
# Checking: 'Aïn Benian' against '64...'
# Checking: 'Aïn Benian' against '65...'
# Checking: 'Aïn Benian' against '66...'
# Checking: 'Aïn Benian' against '67...'
# Checking: 'Aïn Benian' against '68...'
# Checking: 'Aïn Benian' against '69...'
# Checking: 'Aïn Benian' against '70...'
# Checking: 'Aïn Benian' against '71...'
# Checking: 'Aïn Benian' against '72...'
# Checking: 'Aïn Benian' against '73...'
# Checking: 'Aïn Benian' against '74...'
# Checking: 'Aïn Benian' against '75...'
# Checking: 'Aïn Benian' against '76...'
# Checking: 'Aïn Benian' against '77...'
# Checking: 'Aïn Benian' against '78...'
# Checking: 'Aïn Benian' against '79...'
# Checking: 'Aïn Benian' against '80...'
# Checking: 'Aïn Benian' against '81...'
# Checking: 'Aïn Benian' against '82...'
# Checking: 'Aïn Benian' against '83...'
# Checking: 'Aïn Benian' against '84...'
# Checking: 'Aïn Benian' against '85...'
# Checking: 'Aïn Benian' against '86...'
# Checking: 'Aïn Benian' against '87...'
# Checking: 'Aïn Benian' against '88...'
# Checking: 'Aïn Benian' against '89...'
# Checking: 'Aïn Benian' against '90...'
# Checking: 'Aïn Benian' against '91...'
# Checking: 'Aïn Benian' against '92...'
# Checking: 'Aïn Benian' against '93...'
# Checking: 'Aïn Benian' against '94...'
# Checking: 'Aïn Benian' against '95...'
# Checking: 'Aïn Benian' against '96...'
# Checking: 'Aïn Benian' against '97...'
# Checking: 'Aïn Benian' against '98...'
# Checking: 'Aïn Benian' against '99...'
# Checking: 'Aïn Benian' against '100...'
# Checking: 'Aïn Benian' against '101...'
# Checking: 'Aïn Benian' against '102...'
# Checking: 'Aïn Benian' against '103...'
# Checking: 'Aïn Benian' against '104...'
# Checking: 'Aïn Benian' against '105...'
# Checking: 'Aïn Benian' against '106...'
# Checking: 'Aïn Benian' against '107...'
# Checking: 'Aïn Benian' against '108...'
# Checking: 'Aïn Benian' against '109...'
# Checking: 'Aïn Benian' against '110...'
# Checking: 'Aïn Benian' against '111...'
# Checking: 'Aïn Benian' against '112...'
# Checking: 'Aïn Benian' against '113...'
# Checking: 'Aïn Benian' against '114...'
# Checking: 'Aïn Benian' against '115...'
# Checking: 'Aïn Benian' against '116...'
# Checking: 'Aïn Benian' against '117...'
# Checking: 'Aïn Benian' against '118...'
# Checking: 'Aïn Benian' against '119...'
# Checking: 'Aïn Benian' against '120...'
# Checking: 'Aïn Benian' against '121...'
# Checking: 'Aïn Benian' against '122...'
# Checking: 'Aïn Benian' against '123...'
# Checking: 'Aïn Benian' against '124...'
# Checking: 'Aïn Benian' against '125...'
# Checking: 'Aïn Benian' against '126...'
# Checking: 'Aïn Benian' against '127...'
# Checking: 'Aïn Benian' against '128...'
# Checking: 'Aïn Benian' against '129...'
# Checking: 'Aïn Benian' against '130...'
# Checking: 'Aïn Benian' against '131...'
# Checking: 'Aïn Benian' against '132...'
# Checking: 'Aïn Benian' against '133...'
# Checking: 'Aïn Benian' against '134...'
# Checking: 'Aïn Benian' against '135...'
# Checking: 'Aïn Benian' against '136...'
# Checking: 'Aïn Benian' against '137...'
# Checking: 'Aïn Benian' against '138...'
# Checking: 'Aïn Benian' against '139...'
# Checking: 'Aïn Benian' against '140...'
# Checking: 'Aïn Benian' against '141...'
# Checking: 'Aïn Benian' against '142...'
# Checking: 'Aïn Benian' against '143...'
# Checking: 'Aïn Benian' against '144...'
# Checking: 'Aïn Benian' against '145...'
# Checking: 'Aïn Benian' against '146...'
# Checking: 'Aïn Benian' against '147...'
# Checking: 'Aïn Benian' against '148...'
# Checking: 'Aïn Benian' against '149...'
# Checking: 'Aïn Benian' against '150...'
# Checking: 'Aïn Benian' against '151...'
# Checking: 'Aïn Benian' against '152...'
# Checking: 'Aïn Benian' against '153...'
# Checking: 'Aïn Benian' against '154...'
# Checking: 'Aïn Benian' against '155...'
# Checking: 'Aïn Benian' against '156...'
# Checking: 'Aïn Benian' against '157...'
# Checking: 'Aïn Benian' against '158...'
# Checking: 'Aïn Benian' against '159...'
# Checking: 'Aïn Benian' against '160...'
# Checking: 'Aïn Benian' against '161...'
# Checking: 'Aïn Benian' against '162...'
# Checking: 'Aïn Benian' against '163...'
# Checking: 'Aïn Benian' against '164...'
# Checking: 'Aïn Benian' against '165...'
# Checking: 'Aïn Benian' against '166...'
# Checking: 'Aïn Benian' against '167...'
# Checking: 'Aïn Benian' against '168...'
# Checking: 'Aïn Benian' against '169...'
# Checking: 'Aïn Benian' against '170...'
# Checking: 'Aïn Benian' against '171...'
# Checking: 'Aïn Benian' against '172...'
# Checking: 'Aïn Benian' against '173...'
# Checking: 'Aïn Benian' against '174...'
# Checking: 'Aïn Benian' against '175...'
# Checking: 'Aïn Benian' against '176...'
# Checking: 'Aïn Benian' against '177...'
# Checking: 'Aïn Benian' against '178...'
# Checking: 'Aïn Benian' against '179...'
# Checking: 'Aïn Benian' against '180...'
# Checking: 'Aïn Benian' against '181...'
# Checking: 'Aïn Benian' against '182...'
# Checking: 'Aïn Benian' against '183...'
# Checking: 'Aïn Benian' against '184...'
# Checking: 'Aïn Benian' against '185...'
# Checking: 'Aïn Benian' against '186...'
# Checking: 'Aïn Benian' against '187...'
# Checking: 'Aïn Benian' against '188...'
# Checking: 'Aïn Benian' against '189...'
# Checking: 'Aïn Benian' against '190...'
# Checking: 'Aïn Benian' against '191...'
# Checking: 'Aïn Benian' against '192...'
# Checking: 'Aïn Benian' against '193...'
# Checking: 'Aïn Benian' against '194...'
# Checking: 'Aïn Benian' against '195...'
# Checking: 'Aïn Benian' against '196...'
# Checking: 'Aïn Benian' against '197...'
# Checking: 'Aïn Benian' against '198...'
# Checking: 'Aïn Benian' against '199...'
# Checking: 'Aïn Benian' against '200...'
# Checking: 'Aïn Taya' against '1...'
# Checking: 'Aïn Taya' against '2...'
# Checking: 'Aïn Taya' against '3...'
# Checking: 'Aïn Taya' against '4...'
# Checking: 'Aïn Taya' against '5...'
# Checking: 'Aïn Taya' against '6...'
# Checking: 'Aïn Taya' against '7...'
# Checking: 'Aïn Taya' against '8...'
# Checking: 'Aïn Taya' against '9...'
# Checking: 'Aïn Taya' against '10...'
# Checking: 'Aïn Taya' against '11...'
# Checking: 'Aïn Taya' against '12...'
# Checking: 'Aïn Taya' against '13...'
# Checking: 'Aïn Taya' against '14...'
# Checking: 'Aïn Taya' against '15...'
# Checking: 'Aïn Taya' against '16...'
# Checking: 'Aïn Taya' against '17...'
# Checking: 'Aïn Taya' against '18...'
# Checking: 'Aïn Taya' against '19...'
# Checking: 'Aïn Taya' against '20...'
# Checking: 'Aïn Taya' against '21...'
# Checking: 'Aïn Taya' against '22...'
# Checking: 'Aïn Taya' against '23...'
# Checking: 'Aïn Taya' against '24...'
# Checking: 'Aïn Taya' against '25...'
# Checking: 'Aïn Taya' against '26...'
# Checking: 'Aïn Taya' against '27...'
# Checking: 'Aïn Taya' against '28...'
# Checking: 'Aïn Taya' against '29...'
# Checking: 'Aïn Taya' against '30...'
# Checking: 'Aïn Taya' against '31...'
# Checking: 'Aïn Taya' against '32...'
# Checking: 'Aïn Taya' against '33...'
# Checking: 'Aïn Taya' against '34...'
# Checking: 'Aïn Taya' against '35...'
# Checking: 'Aïn Taya' against '36...'
# Checking: 'Aïn Taya' against '37...'
# Checking: 'Aïn Taya' against '38...'
# Checking: 'Aïn Taya' against '39...'
# Checking: 'Aïn Taya' against '40...'
# Checking: 'Aïn Taya' against '41...'
# Checking: 'Aïn Taya' against '42...'
# Checking: 'Aïn Taya' against '43...'
# Checking: 'Aïn Taya' against '44...'
# Checking: 'Aïn Taya' against '45...'
# Checking: 'Aïn Taya' against '46...'
# Checking: 'Aïn Taya' against '47...'
# Checking: 'Aïn Taya' against '48...'
# Checking: 'Aïn Taya' against '49...'
# Checking: 'Aïn Taya' against '50...'
# Checking: 'Aïn Taya' against '51...'
# Checking: 'Aïn Taya' against '52...'
# Checking: 'Aïn Taya' against '53...'
# Checking: 'Aïn Taya' against '54...'
# Checking: 'Aïn Taya' against '55...'
# Checking: 'Aïn Taya' against '56...'
# Checking: 'Aïn Taya' against '57...'
# Checking: 'Aïn Taya' against '58...'
# Checking: 'Aïn Taya' against '59...'
# Checking: 'Aïn Taya' against '60...'
# Checking: 'Aïn Taya' against '61...'
# Checking: 'Aïn Taya' against '62...'
# Checking: 'Aïn Taya' against '63...'
# Checking: 'Aïn Taya' against '64...'
# Checking: 'Aïn Taya' against '65...'
# Checking: 'Aïn Taya' against '66...'
# Checking: 'Aïn Taya' against '67...'
# Checking: 'Aïn Taya' against '68...'
# Checking: 'Aïn Taya' against '69...'
# Checking: 'Aïn Taya' against '70...'
# Checking: 'Aïn Taya' against '71...'
# Checking: 'Aïn Taya' against '72...'
# Checking: 'Aïn Taya' against '73...'
# Checking: 'Aïn Taya' against '74...'
# Checking: 'Aïn Taya' against '75...'
# Checking: 'Aïn Taya' against '76...'
# Checking: 'Aïn Taya' against '77...'
# Checking: 'Aïn Taya' against '78...'
# Checking: 'Aïn Taya' against '79...'
# Checking: 'Aïn Taya' against '80...'
# Checking: 'Aïn Taya' against '81...'
# Checking: 'Aïn Taya' against '82...'
# Checking: 'Aïn Taya' against '83...'
# Checking: 'Aïn Taya' against '84...'
# Checking: 'Aïn Taya' against '85...'
# Checking: 'Aïn Taya' against '86...'
# Checking: 'Aïn Taya' against '87...'
# Checking: 'Aïn Taya' against '88...'
# Checking: 'Aïn Taya' against '89...'
# Checking: 'Aïn Taya' against '90...'
# Checking: 'Aïn Taya' against '91...'
# Checking: 'Aïn Taya' against '92...'
# Checking: 'Aïn Taya' against '93...'
# Checking: 'Aïn Taya' against '94...'
# Checking: 'Aïn Taya' against '95...'
# Checking: 'Aïn Taya' against '96...'
# Checking: 'Aïn Taya' against '97...'
# Checking: 'Aïn Taya' against '98...'
# Checking: 'Aïn Taya' against '99...'
# Checking: 'Aïn Taya' against '100...'
# Checking: 'Aïn Taya' against '101...'
# Checking: 'Aïn Taya' against '102...'
# Checking: 'Aïn Taya' against '103...'
# Checking: 'Aïn Taya' against '104...'
# Checking: 'Aïn Taya' against '105...'
# Checking: 'Aïn Taya' against '106...'
# Checking: 'Aïn Taya' against '107...'
# Checking: 'Aïn Taya' against '108...'
# Checking: 'Aïn Taya' against '109...'
# Checking: 'Aïn Taya' against '110...'
# Checking: 'Aïn Taya' against '111...'
# Checking: 'Aïn Taya' against '112...'
# Checking: 'Aïn Taya' against '113...'
# Checking: 'Aïn Taya' against '114...'
# Checking: 'Aïn Taya' against '115...'
# Checking: 'Aïn Taya' against '116...'
# Checking: 'Aïn Taya' against '117...'
# Checking: 'Aïn Taya' against '118...'
# Checking: 'Aïn Taya' against '119...'
# Checking: 'Aïn Taya' against '120...'
# Checking: 'Aïn Taya' against '121...'
# Checking: 'Aïn Taya' against '122...'
# Checking: 'Aïn Taya' against '123...'
# Checking: 'Aïn Taya' against '124...'
# Checking: 'Aïn Taya' against '125...'
# Checking: 'Aïn Taya' against '126...'
# Checking: 'Aïn Taya' against '127...'
# Checking: 'Aïn Taya' against '128...'
# Checking: 'Aïn Taya' against '129...'
# Checking: 'Aïn Taya' against '130...'
# Checking: 'Aïn Taya' against '131...'
# Checking: 'Aïn Taya' against '132...'
# Checking: 'Aïn Taya' against '133...'
# Checking: 'Aïn Taya' against '134...'
# Checking: 'Aïn Taya' against '135...'
# Checking: 'Aïn Taya' against '136...'
# Checking: 'Aïn Taya' against '137...'
# Checking: 'Aïn Taya' against '138...'
# Checking: 'Aïn Taya' against '139...'
# Checking: 'Aïn Taya' against '140...'
# Checking: 'Aïn Taya' against '141...'
# Checking: 'Aïn Taya' against '142...'
# Checking: 'Aïn Taya' against '143...'
# Checking: 'Aïn Taya' against '144...'
# Checking: 'Aïn Taya' against '145...'
# Checking: 'Aïn Taya' against '146...'
# Checking: 'Aïn Taya' against '147...'
# Checking: 'Aïn Taya' against '148...'
# Checking: 'Aïn Taya' against '149...'
# Checking: 'Aïn Taya' against '150...'
# Checking: 'Aïn Taya' against '151...'
# Checking: 'Aïn Taya' against '152...'
# Checking: 'Aïn Taya' against '153...'
# Checking: 'Aïn Taya' against '154...'
# Checking: 'Aïn Taya' against '155...'
# Checking: 'Aïn Taya' against '156...'
# Checking: 'Aïn Taya' against '157...'
# Checking: 'Aïn Taya' against '158...'
# Checking: 'Aïn Taya' against '159...'
# Checking: 'Aïn Taya' against '160...'
# Checking: 'Aïn Taya' against '161...'
# Checking: 'Aïn Taya' against '162...'
# Checking: 'Aïn Taya' against '163...'
# Checking: 'Aïn Taya' against '164...'
# Checking: 'Aïn Taya' against '165...'
# Checking: 'Aïn Taya' against '166...'
# Checking: 'Aïn Taya' against '167...'
# Checking: 'Aïn Taya' against '168...'
# Checking: 'Aïn Taya' against '169...'
# Checking: 'Aïn Taya' against '170...'
# Checking: 'Aïn Taya' against '171...'
# Checking: 'Aïn Taya' against '172...'
# Checking: 'Aïn Taya' against '173...'
# Checking: 'Aïn Taya' against '174...'
# Checking: 'Aïn Taya' against '175...'
# Checking: 'Aïn Taya' against '176...'
# Checking: 'Aïn Taya' against '177...'
# Checking: 'Aïn Taya' against '178...'
# Checking: 'Aïn Taya' against '179...'
# Checking: 'Aïn Taya' against '180...'
# Checking: 'Aïn Taya' against '181...'
# Checking: 'Aïn Taya' against '182...'
# Checking: 'Aïn Taya' against '183...'
# Checking: 'Aïn Taya' against '184...'
# Checking: 'Aïn Taya' against '185...'
# Checking: 'Aïn Taya' against '186...'
# Checking: 'Aïn Taya' against '187...'
# Checking: 'Aïn Taya' against '188...'
# Checking: 'Aïn Taya' against '189...'
# Checking: 'Aïn Taya' against '190...'
# Checking: 'Aïn Taya' against '191...'
# Checking: 'Aïn Taya' against '192...'
# Checking: 'Aïn Taya' against '193...'
# Checking: 'Aïn Taya' against '194...'
# Checking: 'Aïn Taya' against '195...'
# Checking: 'Aïn Taya' against '196...'
# Checking: 'Aïn Taya' against '197...'
# Checking: 'Aïn Taya' against '198...'
# Checking: 'Aïn Taya' against '199...'
# Checking: 'Aïn Taya' against '200...'
# Checking: 'Baba Hassen' against '1...'
# Checking: 'Baba Hassen' against '2...'
# Checking: 'Baba Hassen' against '3...'
# Checking: 'Baba Hassen' against '4...'
# Checking: 'Baba Hassen' against '5...'
# Checking: 'Baba Hassen' against '6...'
# Checking: 'Baba Hassen' against '7...'
# Checking: 'Baba Hassen' against '8...'
# Checking: 'Baba Hassen' against '9...'
# Checking: 'Baba Hassen' against '10...'
# Checking: 'Baba Hassen' against '11...'
# Checking: 'Baba Hassen' against '12...'
# Checking: 'Baba Hassen' against '13...'
# Checking: 'Baba Hassen' against '14...'
# Checking: 'Baba Hassen' against '15...'
# Checking: 'Baba Hassen' against '16...'
# Checking: 'Baba Hassen' against '17...'
# Checking: 'Baba Hassen' against '18...'
# Checking: 'Baba Hassen' against '19...'
# Checking: 'Baba Hassen' against '20...'
# Checking: 'Baba Hassen' against '21...'
# Checking: 'Baba Hassen' against '22...'
# Checking: 'Baba Hassen' against '23...'
# Checking: 'Baba Hassen' against '24...'
# Checking: 'Baba Hassen' against '25...'
# Checking: 'Baba Hassen' against '26...'
# Checking: 'Baba Hassen' against '27...'
# Checking: 'Baba Hassen' against '28...'
# Checking: 'Baba Hassen' against '29...'
# Checking: 'Baba Hassen' against '30...'
# Checking: 'Baba Hassen' against '31...'
# Checking: 'Baba Hassen' against '32...'
# Checking: 'Baba Hassen' against '33...'
# Checking: 'Baba Hassen' against '34...'
# Checking: 'Baba Hassen' against '35...'
# Checking: 'Baba Hassen' against '36...'
# Checking: 'Baba Hassen' against '37...'
# Checking: 'Baba Hassen' against '38...'
# Checking: 'Baba Hassen' against '39...'
# Checking: 'Baba Hassen' against '40...'
# Checking: 'Baba Hassen' against '41...'
# Checking: 'Baba Hassen' against '42...'
# Checking: 'Baba Hassen' against '43...'
# Checking: 'Baba Hassen' against '44...'
# Checking: 'Baba Hassen' against '45...'
# Checking: 'Baba Hassen' against '46...'
# Checking: 'Baba Hassen' against '47...'
# Checking: 'Baba Hassen' against '48...'
# Checking: 'Baba Hassen' against '49...'
# Checking: 'Baba Hassen' against '50...'
# Checking: 'Baba Hassen' against '51...'
# Checking: 'Baba Hassen' against '52...'
# Checking: 'Baba Hassen' against '53...'
# Checking: 'Baba Hassen' against '54...'
# Checking: 'Baba Hassen' against '55...'
# Checking: 'Baba Hassen' against '56...'
# Checking: 'Baba Hassen' against '57...'
# Checking: 'Baba Hassen' against '58...'
# Checking: 'Baba Hassen' against '59...'
# Checking: 'Baba Hassen' against '60...'
# Checking: 'Baba Hassen' against '61...'
# Checking: 'Baba Hassen' against '62...'
# Checking: 'Baba Hassen' against '63...'
# Checking: 'Baba Hassen' against '64...'
# Checking: 'Baba Hassen' against '65...'
# Checking: 'Baba Hassen' against '66...'
# Checking: 'Baba Hassen' against '67...'
# Checking: 'Baba Hassen' against '68...'
# Checking: 'Baba Hassen' against '69...'
# Checking: 'Baba Hassen' against '70...'
# Checking: 'Baba Hassen' against '71...'
# Checking: 'Baba Hassen' against '72...'
# Checking: 'Baba Hassen' against '73...'
# Checking: 'Baba Hassen' against '74...'
# Checking: 'Baba Hassen' against '75...'
# Checking: 'Baba Hassen' against '76...'
# Checking: 'Baba Hassen' against '77...'
# Checking: 'Baba Hassen' against '78...'
# Checking: 'Baba Hassen' against '79...'
# Checking: 'Baba Hassen' against '80...'
# Checking: 'Baba Hassen' against '81...'
# Checking: 'Baba Hassen' against '82...'
# Checking: 'Baba Hassen' against '83...'
# Checking: 'Baba Hassen' against '84...'
# Checking: 'Baba Hassen' against '85...'
# Checking: 'Baba Hassen' against '86...'
# Checking: 'Baba Hassen' against '87...'
# Checking: 'Baba Hassen' against '88...'
# Checking: 'Baba Hassen' against '89...'
# Checking: 'Baba Hassen' against '90...'
# Checking: 'Baba Hassen' against '91...'
# Checking: 'Baba Hassen' against '92...'
# Checking: 'Baba Hassen' against '93...'
# Checking: 'Baba Hassen' against '94...'
# Checking: 'Baba Hassen' against '95...'
# Checking: 'Baba Hassen' against '96...'
# Checking: 'Baba Hassen' against '97...'
# Checking: 'Baba Hassen' against '98...'
# Checking: 'Baba Hassen' against '99...'
# Checking: 'Baba Hassen' against '100...'
# Checking: 'Baba Hassen' against '101...'
# Checking: 'Baba Hassen' against '102...'
# Checking: 'Baba Hassen' against '103...'
# Checking: 'Baba Hassen' against '104...'
# Checking: 'Baba Hassen' against '105...'
# Checking: 'Baba Hassen' against '106...'
# Checking: 'Baba Hassen' against '107...'
# Checking: 'Baba Hassen' against '108...'
# Checking: 'Baba Hassen' against '109...'
# Checking: 'Baba Hassen' against '110...'
# Checking: 'Baba Hassen' against '111...'
# Checking: 'Baba Hassen' against '112...'
# Checking: 'Baba Hassen' against '113...'
# Checking: 'Baba Hassen' against '114...'
# Checking: 'Baba Hassen' against '115...'
# Checking: 'Baba Hassen' against '116...'
# Checking: 'Baba Hassen' against '117...'
# Checking: 'Baba Hassen' against '118...'
# Checking: 'Baba Hassen' against '119...'
# Checking: 'Baba Hassen' against '120...'
# Checking: 'Baba Hassen' against '121...'
# Checking: 'Baba Hassen' against '122...'
# Checking: 'Baba Hassen' against '123...'
# Checking: 'Baba Hassen' against '124...'
# Checking: 'Baba Hassen' against '125...'
# Checking: 'Baba Hassen' against '126...'
# Checking: 'Baba Hassen' against '127...'
# Checking: 'Baba Hassen' against '128...'
# Checking: 'Baba Hassen' against '129...'
# Checking: 'Baba Hassen' against '130...'
# Checking: 'Baba Hassen' against '131...'
# Checking: 'Baba Hassen' against '132...'
# Checking: 'Baba Hassen' against '133...'
# Checking: 'Baba Hassen' against '134...'
# Checking: 'Baba Hassen' against '135...'
# Checking: 'Baba Hassen' against '136...'
# Checking: 'Baba Hassen' against '137...'
# Checking: 'Baba Hassen' against '138...'
# Checking: 'Baba Hassen' against '139...'
# Checking: 'Baba Hassen' against '140...'
# Checking: 'Baba Hassen' against '141...'
# Checking: 'Baba Hassen' against '142...'
# Checking: 'Baba Hassen' against '143...'
# Checking: 'Baba Hassen' against '144...'
# Checking: 'Baba Hassen' against '145...'
# Checking: 'Baba Hassen' against '146...'
# Checking: 'Baba Hassen' against '147...'
# Checking: 'Baba Hassen' against '148...'
# Checking: 'Baba Hassen' against '149...'
# Checking: 'Baba Hassen' against '150...'
# Checking: 'Baba Hassen' against '151...'
# Checking: 'Baba Hassen' against '152...'
# Checking: 'Baba Hassen' against '153...'
# Checking: 'Baba Hassen' against '154...'
# Checking: 'Baba Hassen' against '155...'
# Checking: 'Baba Hassen' against '156...'
# Checking: 'Baba Hassen' against '157...'
# Checking: 'Baba Hassen' against '158...'
# Checking: 'Baba Hassen' against '159...'
# Checking: 'Baba Hassen' against '160...'
# Checking: 'Baba Hassen' against '161...'
# Checking: 'Baba Hassen' against '162...'
# Checking: 'Baba Hassen' against '163...'
# Checking: 'Baba Hassen' against '164...'
# Checking: 'Baba Hassen' against '165...'
# Checking: 'Baba Hassen' against '166...'
# Checking: 'Baba Hassen' against '167...'
# Checking: 'Baba Hassen' against '168...'
# Checking: 'Baba Hassen' against '169...'
# Checking: 'Baba Hassen' against '170...'
# Checking: 'Baba Hassen' against '171...'
# Checking: 'Baba Hassen' against '172...'
# Checking: 'Baba Hassen' against '173...'
# Checking: 'Baba Hassen' against '174...'
# Checking: 'Baba Hassen' against '175...'
# Checking: 'Baba Hassen' against '176...'
# Checking: 'Baba Hassen' against '177...'
# Checking: 'Baba Hassen' against '178...'
# Checking: 'Baba Hassen' against '179...'
# Checking: 'Baba Hassen' against '180...'
# Checking: 'Baba Hassen' against '181...'
# Checking: 'Baba Hassen' against '182...'
# Checking: 'Baba Hassen' against '183...'
# Checking: 'Baba Hassen' against '184...'
# Checking: 'Baba Hassen' against '185...'
# Checking: 'Baba Hassen' against '186...'
# Checking: 'Baba Hassen' against '187...'
# Checking: 'Baba Hassen' against '188...'
# Checking: 'Baba Hassen' against '189...'
# Checking: 'Baba Hassen' against '190...'
# Checking: 'Baba Hassen' against '191...'
# Checking: 'Baba Hassen' against '192...'
# Checking: 'Baba Hassen' against '193...'
# Checking: 'Baba Hassen' against '194...'
# Checking: 'Baba Hassen' against '195...'
# Checking: 'Baba Hassen' against '196...'
# Checking: 'Baba Hassen' against '197...'
# Checking: 'Baba Hassen' against '198...'
# Checking: 'Baba Hassen' against '199...'
# Checking: 'Baba Hassen' against '200...'
# Checking: 'Bab El Oued' against '1...'
# Checking: 'Bab El Oued' against '2...'
# Checking: 'Bab El Oued' against '3...'
# Checking: 'Bab El Oued' against '4...'
# Checking: 'Bab El Oued' against '5...'
# Checking: 'Bab El Oued' against '6...'
# Checking: 'Bab El Oued' against '7...'
# Checking: 'Bab El Oued' against '8...'
# Checking: 'Bab El Oued' against '9...'
# Checking: 'Bab El Oued' against '10...'
# Checking: 'Bab El Oued' against '11...'
# Checking: 'Bab El Oued' against '12...'
# Checking: 'Bab El Oued' against '13...'
# Checking: 'Bab El Oued' against '14...'
# Checking: 'Bab El Oued' against '15...'
# Checking: 'Bab El Oued' against '16...'
# Checking: 'Bab El Oued' against '17...'
# Checking: 'Bab El Oued' against '18...'
# Checking: 'Bab El Oued' against '19...'
# Checking: 'Bab El Oued' against '20...'
# Checking: 'Bab El Oued' against '21...'
# Checking: 'Bab El Oued' against '22...'
# Checking: 'Bab El Oued' against '23...'
# Checking: 'Bab El Oued' against '24...'
# Checking: 'Bab El Oued' against '25...'
# Checking: 'Bab El Oued' against '26...'
# Checking: 'Bab El Oued' against '27...'
# Checking: 'Bab El Oued' against '28...'
# Checking: 'Bab El Oued' against '29...'
# Checking: 'Bab El Oued' against '30...'
# Checking: 'Bab El Oued' against '31...'
# Checking: 'Bab El Oued' against '32...'
# Checking: 'Bab El Oued' against '33...'
# Checking: 'Bab El Oued' against '34...'
# Checking: 'Bab El Oued' against '35...'
# Checking: 'Bab El Oued' against '36...'
# Checking: 'Bab El Oued' against '37...'
# Checking: 'Bab El Oued' against '38...'
# Checking: 'Bab El Oued' against '39...'
# Checking: 'Bab El Oued' against '40...'
# Checking: 'Bab El Oued' against '41...'
# Checking: 'Bab El Oued' against '42...'
# Checking: 'Bab El Oued' against '43...'
# Checking: 'Bab El Oued' against '44...'
# Checking: 'Bab El Oued' against '45...'
# Checking: 'Bab El Oued' against '46...'
# Checking: 'Bab El Oued' against '47...'
# Checking: 'Bab El Oued' against '48...'
# Checking: 'Bab El Oued' against '49...'
# Checking: 'Bab El Oued' against '50...'
# Checking: 'Bab El Oued' against '51...'
# Checking: 'Bab El Oued' against '52...'
# Checking: 'Bab El Oued' against '53...'
# Checking: 'Bab El Oued' against '54...'
# Checking: 'Bab El Oued' against '55...'
# Checking: 'Bab El Oued' against '56...'
# Checking: 'Bab El Oued' against '57...'
# Checking: 'Bab El Oued' against '58...'
# Checking: 'Bab El Oued' against '59...'
# Checking: 'Bab El Oued' against '60...'
# Checking: 'Bab El Oued' against '61...'
# Checking: 'Bab El Oued' against '62...'
# Checking: 'Bab El Oued' against '63...'
# Checking: 'Bab El Oued' against '64...'
# Checking: 'Bab El Oued' against '65...'
# Checking: 'Bab El Oued' against '66...'
# Checking: 'Bab El Oued' against '67...'
# Checking: 'Bab El Oued' against '68...'
# Checking: 'Bab El Oued' against '69...'
# Checking: 'Bab El Oued' against '70...'
# Checking: 'Bab El Oued' against '71...'
# Checking: 'Bab El Oued' against '72...'
# Checking: 'Bab El Oued' against '73...'
# Checking: 'Bab El Oued' against '74...'
# Checking: 'Bab El Oued' against '75...'
# Checking: 'Bab El Oued' against '76...'
# Checking: 'Bab El Oued' against '77...'
# Checking: 'Bab El Oued' against '78...'
# Checking: 'Bab El Oued' against '79...'
# Checking: 'Bab El Oued' against '80...'
# Checking: 'Bab El Oued' against '81...'
# Checking: 'Bab El Oued' against '82...'
# Checking: 'Bab El Oued' against '83...'
# Checking: 'Bab El Oued' against '84...'
# Checking: 'Bab El Oued' against '85...'
# Checking: 'Bab El Oued' against '86...'
# Checking: 'Bab El Oued' against '87...'
# Checking: 'Bab El Oued' against '88...'
# Checking: 'Bab El Oued' against '89...'
# Checking: 'Bab El Oued' against '90...'
# Checking: 'Bab El Oued' against '91...'
# Checking: 'Bab El Oued' against '92...'
# Checking: 'Bab El Oued' against '93...'
# Checking: 'Bab El Oued' against '94...'
# Checking: 'Bab El Oued' against '95...'
# Checking: 'Bab El Oued' against '96...'
# Checking: 'Bab El Oued' against '97...'
# Checking: 'Bab El Oued' against '98...'
# Checking: 'Bab El Oued' against '99...'
# Checking: 'Bab El Oued' against '100...'
# Checking: 'Bab El Oued' against '101...'
# Checking: 'Bab El Oued' against '102...'
# Checking: 'Bab El Oued' against '103...'
# Checking: 'Bab El Oued' against '104...'
# Checking: 'Bab El Oued' against '105...'
# Checking: 'Bab El Oued' against '106...'
# Checking: 'Bab El Oued' against '107...'
# Checking: 'Bab El Oued' against '108...'
# Checking: 'Bab El Oued' against '109...'
# Checking: 'Bab El Oued' against '110...'
# Checking: 'Bab El Oued' against '111...'
# Checking: 'Bab El Oued' against '112...'
# Checking: 'Bab El Oued' against '113...'
# Checking: 'Bab El Oued' against '114...'
# Checking: 'Bab El Oued' against '115...'
# Checking: 'Bab El Oued' against '116...'
# Checking: 'Bab El Oued' against '117...'
# Checking: 'Bab El Oued' against '118...'
# Checking: 'Bab El Oued' against '119...'
# Checking: 'Bab El Oued' against '120...'
# Checking: 'Bab El Oued' against '121...'
# Checking: 'Bab El Oued' against '122...'
# Checking: 'Bab El Oued' against '123...'
# Checking: 'Bab El Oued' against '124...'
# Checking: 'Bab El Oued' against '125...'
# Checking: 'Bab El Oued' against '126...'
# Checking: 'Bab El Oued' against '127...'
# Checking: 'Bab El Oued' against '128...'
# Checking: 'Bab El Oued' against '129...'
# Checking: 'Bab El Oued' against '130...'
# Checking: 'Bab El Oued' against '131...'
# Checking: 'Bab El Oued' against '132...'
# Checking: 'Bab El Oued' against '133...'
# Checking: 'Bab El Oued' against '134...'
# Checking: 'Bab El Oued' against '135...'
# Checking: 'Bab El Oued' against '136...'
# Checking: 'Bab El Oued' against '137...'
# Checking: 'Bab El Oued' against '138...'
# Checking: 'Bab El Oued' against '139...'
# Checking: 'Bab El Oued' against '140...'
# Checking: 'Bab El Oued' against '141...'
# Checking: 'Bab El Oued' against '142...'
# Checking: 'Bab El Oued' against '143...'
# Checking: 'Bab El Oued' against '144...'
# Checking: 'Bab El Oued' against '145...'
# Checking: 'Bab El Oued' against '146...'
# Checking: 'Bab El Oued' against '147...'
# Checking: 'Bab El Oued' against '148...'
# Checking: 'Bab El Oued' against '149...'
# Checking: 'Bab El Oued' against '150...'
# Checking: 'Bab El Oued' against '151...'
# Checking: 'Bab El Oued' against '152...'
# Checking: 'Bab El Oued' against '153...'
# Checking: 'Bab El Oued' against '154...'
# Checking: 'Bab El Oued' against '155...'
# Checking: 'Bab El Oued' against '156...'
# Checking: 'Bab El Oued' against '157...'
# Checking: 'Bab El Oued' against '158...'
# Checking: 'Bab El Oued' against '159...'
# Checking: 'Bab El Oued' against '160...'
# Checking: 'Bab El Oued' against '161...'
# Checking: 'Bab El Oued' against '162...'
# Checking: 'Bab El Oued' against '163...'
# Checking: 'Bab El Oued' against '164...'
# Checking: 'Bab El Oued' against '165...'
# Checking: 'Bab El Oued' against '166...'
# Checking: 'Bab El Oued' against '167...'
# Checking: 'Bab El Oued' against '168...'
# Checking: 'Bab El Oued' against '169...'
# Checking: 'Bab El Oued' against '170...'
# Checking: 'Bab El Oued' against '171...'
# Checking: 'Bab El Oued' against '172...'
# Checking: 'Bab El Oued' against '173...'
# Checking: 'Bab El Oued' against '174...'
# Checking: 'Bab El Oued' against '175...'
# Checking: 'Bab El Oued' against '176...'
# Checking: 'Bab El Oued' against '177...'
# Checking: 'Bab El Oued' against '178...'
# Checking: 'Bab El Oued' against '179...'
# Checking: 'Bab El Oued' against '180...'
# Checking: 'Bab El Oued' against '181...'
# Checking: 'Bab El Oued' against '182...'
# Checking: 'Bab El Oued' against '183...'
# Checking: 'Bab El Oued' against '184...'
# Checking: 'Bab El Oued' against '185...'
# Checking: 'Bab El Oued' against '186...'
# Checking: 'Bab El Oued' against '187...'
# Checking: 'Bab El Oued' against '188...'
# Checking: 'Bab El Oued' against '189...'
# Checking: 'Bab El Oued' against '190...'
# Checking: 'Bab El Oued' against '191...'
# Checking: 'Bab El Oued' against '192...'
# Checking: 'Bab El Oued' against '193...'
# Checking: 'Bab El Oued' against '194...'
# Checking: 'Bab El Oued' against '195...'
# Checking: 'Bab El Oued' against '196...'
# Checking: 'Bab El Oued' against '197...'
# Checking: 'Bab El Oued' against '198...'
# Checking: 'Bab El Oued' against '199...'
# Checking: 'Bab El Oued' against '200...'
# Checking: 'Bab Ezzouar' against '1...'
# Checking: 'Bab Ezzouar' against '2...'
# Checking: 'Bab Ezzouar' against '3...'
# Checking: 'Bab Ezzouar' against '4...'
# Checking: 'Bab Ezzouar' against '5...'
# Checking: 'Bab Ezzouar' against '6...'
# Checking: 'Bab Ezzouar' against '7...'
# Checking: 'Bab Ezzouar' against '8...'
# Checking: 'Bab Ezzouar' against '9...'
# Checking: 'Bab Ezzouar' against '10...'
# Checking: 'Bab Ezzouar' against '11...'
# Checking: 'Bab Ezzouar' against '12...'
# Checking: 'Bab Ezzouar' against '13...'
# Checking: 'Bab Ezzouar' against '14...'
# Checking: 'Bab Ezzouar' against '15...'
# Checking: 'Bab Ezzouar' against '16...'
# Checking: 'Bab Ezzouar' against '17...'
# Checking: 'Bab Ezzouar' against '18...'
# Checking: 'Bab Ezzouar' against '19...'
# Checking: 'Bab Ezzouar' against '20...'
# Checking: 'Bab Ezzouar' against '21...'
# Checking: 'Bab Ezzouar' against '22...'
# Checking: 'Bab Ezzouar' against '23...'
# Checking: 'Bab Ezzouar' against '24...'
# Checking: 'Bab Ezzouar' against '25...'
# Checking: 'Bab Ezzouar' against '26...'
# Checking: 'Bab Ezzouar' against '27...'
# Checking: 'Bab Ezzouar' against '28...'
# Checking: 'Bab Ezzouar' against '29...'
# Checking: 'Bab Ezzouar' against '30...'
# Checking: 'Bab Ezzouar' against '31...'
# Checking: 'Bab Ezzouar' against '32...'
# Checking: 'Bab Ezzouar' against '33...'
# Checking: 'Bab Ezzouar' against '34...'
# Checking: 'Bab Ezzouar' against '35...'
# Checking: 'Bab Ezzouar' against '36...'
# Checking: 'Bab Ezzouar' against '37...'
# Checking: 'Bab Ezzouar' against '38...'
# Checking: 'Bab Ezzouar' against '39...'
# Checking: 'Bab Ezzouar' against '40...'
# Checking: 'Bab Ezzouar' against '41...'
# Checking: 'Bab Ezzouar' against '42...'
# Checking: 'Bab Ezzouar' against '43...'
# Checking: 'Bab Ezzouar' against '44...'
# Checking: 'Bab Ezzouar' against '45...'
# Checking: 'Bab Ezzouar' against '46...'
# Checking: 'Bab Ezzouar' against '47...'
# Checking: 'Bab Ezzouar' against '48...'
# Checking: 'Bab Ezzouar' against '49...'
# Checking: 'Bab Ezzouar' against '50...'
# Checking: 'Bab Ezzouar' against '51...'
# Checking: 'Bab Ezzouar' against '52...'
# Checking: 'Bab Ezzouar' against '53...'
# Checking: 'Bab Ezzouar' against '54...'
# Checking: 'Bab Ezzouar' against '55...'
# Checking: 'Bab Ezzouar' against '56...'
# Checking: 'Bab Ezzouar' against '57...'
# Checking: 'Bab Ezzouar' against '58...'
# Checking: 'Bab Ezzouar' against '59...'
# Checking: 'Bab Ezzouar' against '60...'
# Checking: 'Bab Ezzouar' against '61...'
# Checking: 'Bab Ezzouar' against '62...'
# Checking: 'Bab Ezzouar' against '63...'
# Checking: 'Bab Ezzouar' against '64...'
# Checking: 'Bab Ezzouar' against '65...'
# Checking: 'Bab Ezzouar' against '66...'
# Checking: 'Bab Ezzouar' against '67...'
# Checking: 'Bab Ezzouar' against '68...'
# Checking: 'Bab Ezzouar' against '69...'
# Checking: 'Bab Ezzouar' against '70...'
# Checking: 'Bab Ezzouar' against '71...'
# Checking: 'Bab Ezzouar' against '72...'
# Checking: 'Bab Ezzouar' against '73...'
# Checking: 'Bab Ezzouar' against '74...'
# Checking: 'Bab Ezzouar' against '75...'
# Checking: 'Bab Ezzouar' against '76...'
# Checking: 'Bab Ezzouar' against '77...'
# Checking: 'Bab Ezzouar' against '78...'
# Checking: 'Bab Ezzouar' against '79...'
# Checking: 'Bab Ezzouar' against '80...'
# Checking: 'Bab Ezzouar' against '81...'
# Checking: 'Bab Ezzouar' against '82...'
# Checking: 'Bab Ezzouar' against '83...'
# Checking: 'Bab Ezzouar' against '84...'
# Checking: 'Bab Ezzouar' against '85...'
# Checking: 'Bab Ezzouar' against '86...'
# Checking: 'Bab Ezzouar' against '87...'
# Checking: 'Bab Ezzouar' against '88...'
# Checking: 'Bab Ezzouar' against '89...'
# Checking: 'Bab Ezzouar' against '90...'
# Checking: 'Bab Ezzouar' against '91...'
# Checking: 'Bab Ezzouar' against '92...'
# Checking: 'Bab Ezzouar' against '93...'
# Checking: 'Bab Ezzouar' against '94...'
# Checking: 'Bab Ezzouar' against '95...'
# Checking: 'Bab Ezzouar' against '96...'
# Checking: 'Bab Ezzouar' against '97...'
# Checking: 'Bab Ezzouar' against '98...'
# Checking: 'Bab Ezzouar' against '99...'
# Checking: 'Bab Ezzouar' against '100...'
# Checking: 'Bab Ezzouar' against '101...'
# Checking: 'Bab Ezzouar' against '102...'
# Checking: 'Bab Ezzouar' against '103...'
# Checking: 'Bab Ezzouar' against '104...'
# Checking: 'Bab Ezzouar' against '105...'
# Checking: 'Bab Ezzouar' against '106...'
# Checking: 'Bab Ezzouar' against '107...'
# Checking: 'Bab Ezzouar' against '108...'
# Checking: 'Bab Ezzouar' against '109...'
# Checking: 'Bab Ezzouar' against '110...'
# Checking: 'Bab Ezzouar' against '111...'
# Checking: 'Bab Ezzouar' against '112...'
# Checking: 'Bab Ezzouar' against '113...'
# Checking: 'Bab Ezzouar' against '114...'
# Checking: 'Bab Ezzouar' against '115...'
# Checking: 'Bab Ezzouar' against '116...'
# Checking: 'Bab Ezzouar' against '117...'
# Checking: 'Bab Ezzouar' against '118...'
# Checking: 'Bab Ezzouar' against '119...'
# Checking: 'Bab Ezzouar' against '120...'
# Checking: 'Bab Ezzouar' against '121...'
# Checking: 'Bab Ezzouar' against '122...'
# Checking: 'Bab Ezzouar' against '123...'
# Checking: 'Bab Ezzouar' against '124...'
# Checking: 'Bab Ezzouar' against '125...'
# Checking: 'Bab Ezzouar' against '126...'
# Checking: 'Bab Ezzouar' against '127...'
# Checking: 'Bab Ezzouar' against '128...'
# Checking: 'Bab Ezzouar' against '129...'
# Checking: 'Bab Ezzouar' against '130...'
# Checking: 'Bab Ezzouar' against '131...'
# Checking: 'Bab Ezzouar' against '132...'
# Checking: 'Bab Ezzouar' against '133...'
# Checking: 'Bab Ezzouar' against '134...'
# Checking: 'Bab Ezzouar' against '135...'
# Checking: 'Bab Ezzouar' against '136...'
# Checking: 'Bab Ezzouar' against '137...'
# Checking: 'Bab Ezzouar' against '138...'
# Checking: 'Bab Ezzouar' against '139...'
# Checking: 'Bab Ezzouar' against '140...'
# Checking: 'Bab Ezzouar' against '141...'
# Checking: 'Bab Ezzouar' against '142...'
# Checking: 'Bab Ezzouar' against '143...'
# Checking: 'Bab Ezzouar' against '144...'
# Checking: 'Bab Ezzouar' against '145...'
# Checking: 'Bab Ezzouar' against '146...'
# Checking: 'Bab Ezzouar' against '147...'
# Checking: 'Bab Ezzouar' against '148...'
# Checking: 'Bab Ezzouar' against '149...'
# Checking: 'Bab Ezzouar' against '150...'
# Checking: 'Bab Ezzouar' against '151...'
# Checking: 'Bab Ezzouar' against '152...'
# Checking: 'Bab Ezzouar' against '153...'
# Checking: 'Bab Ezzouar' against '154...'
# Checking: 'Bab Ezzouar' against '155...'
# Checking: 'Bab Ezzouar' against '156...'
# Checking: 'Bab Ezzouar' against '157...'
# Checking: 'Bab Ezzouar' against '158...'
# Checking: 'Bab Ezzouar' against '159...'
# Checking: 'Bab Ezzouar' against '160...'
# Checking: 'Bab Ezzouar' against '161...'
# Checking: 'Bab Ezzouar' against '162...'
# Checking: 'Bab Ezzouar' against '163...'
# Checking: 'Bab Ezzouar' against '164...'
# Checking: 'Bab Ezzouar' against '165...'
# Checking: 'Bab Ezzouar' against '166...'
# Checking: 'Bab Ezzouar' against '167...'
# Checking: 'Bab Ezzouar' against '168...'
# Checking: 'Bab Ezzouar' against '169...'
# Checking: 'Bab Ezzouar' against '170...'
# Checking: 'Bab Ezzouar' against '171...'
# Checking: 'Bab Ezzouar' against '172...'
# Checking: 'Bab Ezzouar' against '173...'
# Checking: 'Bab Ezzouar' against '174...'
# Checking: 'Bab Ezzouar' against '175...'
# Checking: 'Bab Ezzouar' against '176...'
# Checking: 'Bab Ezzouar' against '177...'
# Checking: 'Bab Ezzouar' against '178...'
# Checking: 'Bab Ezzouar' against '179...'
# Checking: 'Bab Ezzouar' against '180...'
# Checking: 'Bab Ezzouar' against '181...'
# Checking: 'Bab Ezzouar' against '182...'
# Checking: 'Bab Ezzouar' against '183...'
# Checking: 'Bab Ezzouar' against '184...'
# Checking: 'Bab Ezzouar' against '185...'
# Checking: 'Bab Ezzouar' against '186...'
# Checking: 'Bab Ezzouar' against '187...'
# Checking: 'Bab Ezzouar' against '188...'
# Checking: 'Bab Ezzouar' against '189...'
# Checking: 'Bab Ezzouar' against '190...'
# Checking: 'Bab Ezzouar' against '191...'
# Checking: 'Bab Ezzouar' against '192...'
# Checking: 'Bab Ezzouar' against '193...'
# Checking: 'Bab Ezzouar' against '194...'
# Checking: 'Bab Ezzouar' against '195...'
# Checking: 'Bab Ezzouar' against '196...'
# Checking: 'Bab Ezzouar' against '197...'
# Checking: 'Bab Ezzouar' against '198...'
# Checking: 'Bab Ezzouar' against '199...'
# Checking: 'Bab Ezzouar' against '200...'
# Checking: 'Bachdjerrah' against '1...'
# Checking: 'Bachdjerrah' against '2...'
# Checking: 'Bachdjerrah' against '3...'
# Checking: 'Bachdjerrah' against '4...'
# Checking: 'Bachdjerrah' against '5...'
# Checking: 'Bachdjerrah' against '6...'
# Checking: 'Bachdjerrah' against '7...'
# Checking: 'Bachdjerrah' against '8...'
# Checking: 'Bachdjerrah' against '9...'
# Checking: 'Bachdjerrah' against '10...'
# Checking: 'Bachdjerrah' against '11...'
# Checking: 'Bachdjerrah' against '12...'
# Checking: 'Bachdjerrah' against '13...'
# Checking: 'Bachdjerrah' against '14...'
# Checking: 'Bachdjerrah' against '15...'
# Checking: 'Bachdjerrah' against '16...'
# Checking: 'Bachdjerrah' against '17...'
# Checking: 'Bachdjerrah' against '18...'
# Checking: 'Bachdjerrah' against '19...'
# Checking: 'Bachdjerrah' against '20...'
# Checking: 'Bachdjerrah' against '21...'
# Checking: 'Bachdjerrah' against '22...'
# Checking: 'Bachdjerrah' against '23...'
# Checking: 'Bachdjerrah' against '24...'
# Checking: 'Bachdjerrah' against '25...'
# Checking: 'Bachdjerrah' against '26...'
# Checking: 'Bachdjerrah' against '27...'
# Checking: 'Bachdjerrah' against '28...'
# Checking: 'Bachdjerrah' against '29...'
# Checking: 'Bachdjerrah' against '30...'
# Checking: 'Bachdjerrah' against '31...'
# Checking: 'Bachdjerrah' against '32...'
# Checking: 'Bachdjerrah' against '33...'
# Checking: 'Bachdjerrah' against '34...'
# Checking: 'Bachdjerrah' against '35...'
# Checking: 'Bachdjerrah' against '36...'
# Checking: 'Bachdjerrah' against '37...'
# Checking: 'Bachdjerrah' against '38...'
# Checking: 'Bachdjerrah' against '39...'
# Checking: 'Bachdjerrah' against '40...'
# Checking: 'Bachdjerrah' against '41...'
# Checking: 'Bachdjerrah' against '42...'
# Checking: 'Bachdjerrah' against '43...'
# Checking: 'Bachdjerrah' against '44...'
# Checking: 'Bachdjerrah' against '45...'
# Checking: 'Bachdjerrah' against '46...'
# Checking: 'Bachdjerrah' against '47...'
# Checking: 'Bachdjerrah' against '48...'
# Checking: 'Bachdjerrah' against '49...'
# Checking: 'Bachdjerrah' against '50...'
# Checking: 'Bachdjerrah' against '51...'
# Checking: 'Bachdjerrah' against '52...'
# Checking: 'Bachdjerrah' against '53...'
# Checking: 'Bachdjerrah' against '54...'
# Checking: 'Bachdjerrah' against '55...'
# Checking: 'Bachdjerrah' against '56...'
# Checking: 'Bachdjerrah' against '57...'
# Checking: 'Bachdjerrah' against '58...'
# Checking: 'Bachdjerrah' against '59...'
# Checking: 'Bachdjerrah' against '60...'
# Checking: 'Bachdjerrah' against '61...'
# Checking: 'Bachdjerrah' against '62...'
# Checking: 'Bachdjerrah' against '63...'
# Checking: 'Bachdjerrah' against '64...'
# Checking: 'Bachdjerrah' against '65...'
# Checking: 'Bachdjerrah' against '66...'
# Checking: 'Bachdjerrah' against '67...'
# Checking: 'Bachdjerrah' against '68...'
# Checking: 'Bachdjerrah' against '69...'
# Checking: 'Bachdjerrah' against '70...'
# Checking: 'Bachdjerrah' against '71...'
# Checking: 'Bachdjerrah' against '72...'
# Checking: 'Bachdjerrah' against '73...'
# Checking: 'Bachdjerrah' against '74...'
# Checking: 'Bachdjerrah' against '75...'
# Checking: 'Bachdjerrah' against '76...'
# Checking: 'Bachdjerrah' against '77...'
# Checking: 'Bachdjerrah' against '78...'
# Checking: 'Bachdjerrah' against '79...'
# Checking: 'Bachdjerrah' against '80...'
# Checking: 'Bachdjerrah' against '81...'
# Checking: 'Bachdjerrah' against '82...'
# Checking: 'Bachdjerrah' against '83...'
# Checking: 'Bachdjerrah' against '84...'
# Checking: 'Bachdjerrah' against '85...'
# Checking: 'Bachdjerrah' against '86...'
# Checking: 'Bachdjerrah' against '87...'
# Checking: 'Bachdjerrah' against '88...'
# Checking: 'Bachdjerrah' against '89...'
# Checking: 'Bachdjerrah' against '90...'
# Checking: 'Bachdjerrah' against '91...'
# Checking: 'Bachdjerrah' against '92...'
# Checking: 'Bachdjerrah' against '93...'
# Checking: 'Bachdjerrah' against '94...'
# Checking: 'Bachdjerrah' against '95...'
# Checking: 'Bachdjerrah' against '96...'
# Checking: 'Bachdjerrah' against '97...'
# Checking: 'Bachdjerrah' against '98...'
# Checking: 'Bachdjerrah' against '99...'
# Checking: 'Bachdjerrah' against '100...'
# Checking: 'Bachdjerrah' against '101...'
# Checking: 'Bachdjerrah' against '102...'
# Checking: 'Bachdjerrah' against '103...'
# Checking: 'Bachdjerrah' against '104...'
# Checking: 'Bachdjerrah' against '105...'
# Checking: 'Bachdjerrah' against '106...'
# Checking: 'Bachdjerrah' against '107...'
# Checking: 'Bachdjerrah' against '108...'
# Checking: 'Bachdjerrah' against '109...'
# Checking: 'Bachdjerrah' against '110...'
# Checking: 'Bachdjerrah' against '111...'
# Checking: 'Bachdjerrah' against '112...'
# Checking: 'Bachdjerrah' against '113...'
# Checking: 'Bachdjerrah' against '114...'
# Checking: 'Bachdjerrah' against '115...'
# Checking: 'Bachdjerrah' against '116...'
# Checking: 'Bachdjerrah' against '117...'
# Checking: 'Bachdjerrah' against '118...'
# Checking: 'Bachdjerrah' against '119...'
# Checking: 'Bachdjerrah' against '120...'
# Checking: 'Bachdjerrah' against '121...'
# Checking: 'Bachdjerrah' against '122...'
# Checking: 'Bachdjerrah' against '123...'
# Checking: 'Bachdjerrah' against '124...'
# Checking: 'Bachdjerrah' against '125...'
# Checking: 'Bachdjerrah' against '126...'
# Checking: 'Bachdjerrah' against '127...'
# Checking: 'Bachdjerrah' against '128...'
# Checking: 'Bachdjerrah' against '129...'
# Checking: 'Bachdjerrah' against '130...'
# Checking: 'Bachdjerrah' against '131...'
# Checking: 'Bachdjerrah' against '132...'
# Checking: 'Bachdjerrah' against '133...'
# Checking: 'Bachdjerrah' against '134...'
# Checking: 'Bachdjerrah' against '135...'
# Checking: 'Bachdjerrah' against '136...'
# Checking: 'Bachdjerrah' against '137...'
# Checking: 'Bachdjerrah' against '138...'
# Checking: 'Bachdjerrah' against '139...'
# Checking: 'Bachdjerrah' against '140...'
# Checking: 'Bachdjerrah' against '141...'
# Checking: 'Bachdjerrah' against '142...'
# Checking: 'Bachdjerrah' against '143...'
# Checking: 'Bachdjerrah' against '144...'
# Checking: 'Bachdjerrah' against '145...'
# Checking: 'Bachdjerrah' against '146...'
# Checking: 'Bachdjerrah' against '147...'
# Checking: 'Bachdjerrah' against '148...'
# Checking: 'Bachdjerrah' against '149...'
# Checking: 'Bachdjerrah' against '150...'
# Checking: 'Bachdjerrah' against '151...'
# Checking: 'Bachdjerrah' against '152...'
# Checking: 'Bachdjerrah' against '153...'
# Checking: 'Bachdjerrah' against '154...'
# Checking: 'Bachdjerrah' against '155...'
# Checking: 'Bachdjerrah' against '156...'
# Checking: 'Bachdjerrah' against '157...'
# Checking: 'Bachdjerrah' against '158...'
# Checking: 'Bachdjerrah' against '159...'
# Checking: 'Bachdjerrah' against '160...'
# Checking: 'Bachdjerrah' against '161...'
# Checking: 'Bachdjerrah' against '162...'
# Checking: 'Bachdjerrah' against '163...'
# Checking: 'Bachdjerrah' against '164...'
# Checking: 'Bachdjerrah' against '165...'
# Checking: 'Bachdjerrah' against '166...'
# Checking: 'Bachdjerrah' against '167...'
# Checking: 'Bachdjerrah' against '168...'
# Checking: 'Bachdjerrah' against '169...'
# Checking: 'Bachdjerrah' against '170...'
# Checking: 'Bachdjerrah' against '171...'
# Checking: 'Bachdjerrah' against '172...'
# Checking: 'Bachdjerrah' against '173...'
# Checking: 'Bachdjerrah' against '174...'
# Checking: 'Bachdjerrah' against '175...'
# Checking: 'Bachdjerrah' against '176...'
# Checking: 'Bachdjerrah' against '177...'
# Checking: 'Bachdjerrah' against '178...'
# Checking: 'Bachdjerrah' against '179...'
# Checking: 'Bachdjerrah' against '180...'
# Checking: 'Bachdjerrah' against '181...'
# Checking: 'Bachdjerrah' against '182...'
# Checking: 'Bachdjerrah' against '183...'
# Checking: 'Bachdjerrah' against '184...'
# Checking: 'Bachdjerrah' against '185...'
# Checking: 'Bachdjerrah' against '186...'
# Checking: 'Bachdjerrah' against '187...'
# Checking: 'Bachdjerrah' against '188...'
# Checking: 'Bachdjerrah' against '189...'
# Checking: 'Bachdjerrah' against '190...'
# Checking: 'Bachdjerrah' against '191...'
# Checking: 'Bachdjerrah' against '192...'
# Checking: 'Bachdjerrah' against '193...'
# Checking: 'Bachdjerrah' against '194...'
# Checking: 'Bachdjerrah' against '195...'
# Checking: 'Bachdjerrah' against '196...'
# Checking: 'Bachdjerrah' against '197...'
# Checking: 'Bachdjerrah' against '198...'
# Checking: 'Bachdjerrah' against '199...'
# Checking: 'Bachdjerrah' against '200...'
# Checking: 'Baraki' against '1...'
# Checking: 'Baraki' against '2...'
# ...
# Checking: 'Zéralda' against '49...'
# Checking: 'Zéralda' against '50...'
# Checking: 'Zéralda' against '51...'
# Checking: 'Zéralda' against '52...'
# Checking: 'Zéralda' against '53...'
# Checking: 'Zéralda' against '54...'
# Checking: 'Zéralda' against '55...'
# Checking: 'Zéralda' against '56...'
# Checking: 'Zéralda' against '57...'
# Checking: 'Zéralda' against '58...'
# Checking: 'Zéralda' against '59...'
# Checking: 'Zéralda' against '60...'
# Checking: 'Zéralda' against '61...'
# Checking: 'Zéralda' against '62...'
# Checking: 'Zéralda' against '63...'
# Checking: 'Zéralda' against '64...'
# Checking: 'Zéralda' against '65...'
# Checking: 'Zéralda' against '66...'
# Checking: 'Zéralda' against '67...'
# Checking: 'Zéralda' against '68...'
# Checking: 'Zéralda' against '69...'
# Checking: 'Zéralda' against '70...'
# Checking: 'Zéralda' against '71...'
# Checking: 'Zéralda' against '72...'
# Checking: 'Zéralda' against '73...'
# Checking: 'Zéralda' against '74...'
# Checking: 'Zéralda' against '75...'
# Checking: 'Zéralda' against '76...'
# Checking: 'Zéralda' against '77...'
# Checking: 'Zéralda' against '78...'
# Checking: 'Zéralda' against '79...'
# Checking: 'Zéralda' against '80...'
# Checking: 'Zéralda' against '81...'
# Checking: 'Zéralda' against '82...'
# Checking: 'Zéralda' against '83...'
# Checking: 'Zéralda' against '84...'
# Checking: 'Zéralda' against '85...'
# Checking: 'Zéralda' against '86...'
# Checking: 'Zéralda' against '87...'
# Checking: 'Zéralda' against '88...'
# Checking: 'Zéralda' against '89...'
# Checking: 'Zéralda' against '90...'
# Checking: 'Zéralda' against '91...'
# Checking: 'Zéralda' against '92...'
# Checking: 'Zéralda' against '93...'
# Checking: 'Zéralda' against '94...'
# Checking: 'Zéralda' against '95...'
# Checking: 'Zéralda' against '96...'
# Checking: 'Zéralda' against '97...'
# Checking: 'Zéralda' against '98...'
# Checking: 'Zéralda' against '99...'
# Checking: 'Zéralda' against '100...'
# Checking: 'Zéralda' against '101...'
# Checking: 'Zéralda' against '102...'
# Checking: 'Zéralda' against '103...'
# Checking: 'Zéralda' against '104...'
# Checking: 'Zéralda' against '105...'
# Checking: 'Zéralda' against '106...'
# Checking: 'Zéralda' against '107...'
# Checking: 'Zéralda' against '108...'
# Checking: 'Zéralda' against '109...'
# Checking: 'Zéralda' against '110...'
# Checking: 'Zéralda' against '111...'
# Checking: 'Zéralda' against '112...'
# Checking: 'Zéralda' against '113...'
# Checking: 'Zéralda' against '114...'
# Checking: 'Zéralda' against '115...'
# Checking: 'Zéralda' against '116...'
# Checking: 'Zéralda' against '117...'
# Checking: 'Zéralda' against '118...'
# Checking: 'Zéralda' against '119...'
# Checking: 'Zéralda' against '120...'
# Checking: 'Zéralda' against '121...'
# Checking: 'Zéralda' against '122...'
# Checking: 'Zéralda' against '123...'
# Checking: 'Zéralda' against '124...'
# Checking: 'Zéralda' against '125...'
# Checking: 'Zéralda' against '126...'
# Checking: 'Zéralda' against '127...'
# Checking: 'Zéralda' against '128...'
# Checking: 'Zéralda' against '129...'
# Checking: 'Zéralda' against '130...'
# Checking: 'Zéralda' against '131...'
# Checking: 'Zéralda' against '132...'
# Checking: 'Zéralda' against '133...'
# Checking: 'Zéralda' against '134...'
# Checking: 'Zéralda' against '135...'
# Checking: 'Zéralda' against '136...'
# Checking: 'Zéralda' against '137...'
# Checking: 'Zéralda' against '138...'
# Checking: 'Zéralda' against '139...'
# Checking: 'Zéralda' against '140...'
# Checking: 'Zéralda' against '141...'
# Checking: 'Zéralda' against '142...'
# Checking: 'Zéralda' against '143...'
# Checking: 'Zéralda' against '144...'
# Checking: 'Zéralda' against '145...'
# Checking: 'Zéralda' against '146...'
# Checking: 'Zéralda' against '147...'
# Checking: 'Zéralda' against '148...'
# Checking: 'Zéralda' against '149...'
# Checking: 'Zéralda' against '150...'
# Checking: 'Zéralda' against '151...'
# Checking: 'Zéralda' against '152...'
# Checking: 'Zéralda' against '153...'
# Checking: 'Zéralda' against '154...'
# Checking: 'Zéralda' against '155...'
# Checking: 'Zéralda' against '156...'
# Checking: 'Zéralda' against '157...'
# Checking: 'Zéralda' against '158...'
# Checking: 'Zéralda' against '159...'
# Checking: 'Zéralda' against '160...'
# Checking: 'Zéralda' against '161...'
# Checking: 'Zéralda' against '162...'
# Checking: 'Zéralda' against '163...'
# Checking: 'Zéralda' against '164...'
# Checking: 'Zéralda' against '165...'
# Checking: 'Zéralda' against '166...'
# Checking: 'Zéralda' against '167...'
# Checking: 'Zéralda' against '168...'
# Checking: 'Zéralda' against '169...'
# Checking: 'Zéralda' against '170...'
# Checking: 'Zéralda' against '171...'
# Checking: 'Zéralda' against '172...'
# Checking: 'Zéralda' against '173...'
# Checking: 'Zéralda' against '174...'
# Checking: 'Zéralda' against '175...'
# Checking: 'Zéralda' against '176...'
# Checking: 'Zéralda' against '177...'
# Checking: 'Zéralda' against '178...'
# Checking: 'Zéralda' against '179...'
# Checking: 'Zéralda' against '180...'
# Checking: 'Zéralda' against '181...'
# Checking: 'Zéralda' against '182...'
# Checking: 'Zéralda' against '183...'
# Checking: 'Zéralda' against '184...'
# Checking: 'Zéralda' against '185...'
# Checking: 'Zéralda' against '186...'
# Checking: 'Zéralda' against '187...'
# Checking: 'Zéralda' against '188...'
# Checking: 'Zéralda' against '189...'
# Checking: 'Zéralda' against '190...'
# Checking: 'Zéralda' against '191...'
# Checking: 'Zéralda' against '192...'
# Checking: 'Zéralda' against '193...'
# Checking: 'Zéralda' against '194...'
# Checking: 'Zéralda' against '195...'
# Checking: 'Zéralda' against '196...'
# Checking: 'Zéralda' against '197...'
# Checking: 'Zéralda' against '198...'
# Checking: 'Zéralda' against '199...'
# Checking: 'Zéralda' against '200...'
# Checking: 'Algérie [Algeria]' against '1...'
# Checking: 'Algérie [Algeria]' against '2...'
# Checking: 'Algérie [Algeria]' against '3...'
# Checking: 'Algérie [Algeria]' against '4...'
# Checking: 'Algérie [Algeria]' against '5...'
# Checking: 'Algérie [Algeria]' against '6...'
# Checking: 'Algérie [Algeria]' against '7...'
# Checking: 'Algérie [Algeria]' against '8...'
# Checking: 'Algérie [Algeria]' against '9...'
# Checking: 'Algérie [Algeria]' against '10...'
# Checking: 'Algérie [Algeria]' against '11...'
# Checking: 'Algérie [Algeria]' against '12...'
# Checking: 'Algérie [Algeria]' against '13...'
# Checking: 'Algérie [Algeria]' against '14...'
# Checking: 'Algérie [Algeria]' against '15...'
# Checking: 'Algérie [Algeria]' against '16...'
# Checking: 'Algérie [Algeria]' against '17...'
# Checking: 'Algérie [Algeria]' against '18...'
# Checking: 'Algérie [Algeria]' against '19...'
# Checking: 'Algérie [Algeria]' against '20...'
# Checking: 'Algérie [Algeria]' against '21...'
# Checking: 'Algérie [Algeria]' against '22...'
# Checking: 'Algérie [Algeria]' against '23...'
# Checking: 'Algérie [Algeria]' against '24...'
# Checking: 'Algérie [Algeria]' against '25...'
# Checking: 'Algérie [Algeria]' against '26...'
# Checking: 'Algérie [Algeria]' against '27...'
# Checking: 'Algérie [Algeria]' against '28...'
# Checking: 'Algérie [Algeria]' against '29...'
# Checking: 'Algérie [Algeria]' against '30...'
# Checking: 'Algérie [Algeria]' against '31...'
# Checking: 'Algérie [Algeria]' against '32...'
# Checking: 'Algérie [Algeria]' against '33...'
# Checking: 'Algérie [Algeria]' against '34...'
# Checking: 'Algérie [Algeria]' against '35...'
# Checking: 'Algérie [Algeria]' against '36...'
# Checking: 'Algérie [Algeria]' against '37...'
# Checking: 'Algérie [Algeria]' against '38...'
# Checking: 'Algérie [Algeria]' against '39...'
# Checking: 'Algérie [Algeria]' against '40...'
# Checking: 'Algérie [Algeria]' against '41...'
# Checking: 'Algérie [Algeria]' against '42...'
# Checking: 'Algérie [Algeria]' against '43...'
# Checking: 'Algérie [Algeria]' against '44...'
# Checking: 'Algérie [Algeria]' against '45...'
# Checking: 'Algérie [Algeria]' against '46...'
# Checking: 'Algérie [Algeria]' against '47...'
# Checking: 'Algérie [Algeria]' against '48...'
# Checking: 'Algérie [Algeria]' against '49...'
# Checking: 'Algérie [Algeria]' against '50...'
# Checking: 'Algérie [Algeria]' against '51...'
# Checking: 'Algérie [Algeria]' against '52...'
# Checking: 'Algérie [Algeria]' against '53...'
# Checking: 'Algérie [Algeria]' against '54...'
# Checking: 'Algérie [Algeria]' against '55...'
# Checking: 'Algérie [Algeria]' against '56...'
# Checking: 'Algérie [Algeria]' against '57...'
# Checking: 'Algérie [Algeria]' against '58...'
# Checking: 'Algérie [Algeria]' against '59...'
# Checking: 'Algérie [Algeria]' against '60...'
# Checking: 'Algérie [Algeria]' against '61...'
# Checking: 'Algérie [Algeria]' against '62...'
# Checking: 'Algérie [Algeria]' against '63...'
# Checking: 'Algérie [Algeria]' against '64...'
# Checking: 'Algérie [Algeria]' against '65...'
# Checking: 'Algérie [Algeria]' against '66...'
# Checking: 'Algérie [Algeria]' against '67...'
# Checking: 'Algérie [Algeria]' against '68...'
# Checking: 'Algérie [Algeria]' against '69...'
# Checking: 'Algérie [Algeria]' against '70...'
# Checking: 'Algérie [Algeria]' against '71...'
# Checking: 'Algérie [Algeria]' against '72...'
# Checking: 'Algérie [Algeria]' against '73...'
# Checking: 'Algérie [Algeria]' against '74...'
# Checking: 'Algérie [Algeria]' against '75...'
# Checking: 'Algérie [Algeria]' against '76...'
# Checking: 'Algérie [Algeria]' against '77...'
# Checking: 'Algérie [Algeria]' against '78...'
# Checking: 'Algérie [Algeria]' against '79...'
# Checking: 'Algérie [Algeria]' against '80...'
# Checking: 'Algérie [Algeria]' against '81...'
# Checking: 'Algérie [Algeria]' against '82...'
# Checking: 'Algérie [Algeria]' against '83...'
# Checking: 'Algérie [Algeria]' against '84...'
# Checking: 'Algérie [Algeria]' against '85...'
# Checking: 'Algérie [Algeria]' against '86...'
# Checking: 'Algérie [Algeria]' against '87...'
# Checking: 'Algérie [Algeria]' against '88...'
# Checking: 'Algérie [Algeria]' against '89...'
# Checking: 'Algérie [Algeria]' against '90...'
# Checking: 'Algérie [Algeria]' against '91...'
# Checking: 'Algérie [Algeria]' against '92...'
# Checking: 'Algérie [Algeria]' against '93...'
# Checking: 'Algérie [Algeria]' against '94...'
# Checking: 'Algérie [Algeria]' against '95...'
# Checking: 'Algérie [Algeria]' against '96...'
# Checking: 'Algérie [Algeria]' against '97...'
# Checking: 'Algérie [Algeria]' against '98...'
# Checking: 'Algérie [Algeria]' against '99...'
# Checking: 'Algérie [Algeria]' against '100...'
# Checking: 'Algérie [Algeria]' against '101...'
# Checking: 'Algérie [Algeria]' against '102...'
# Checking: 'Algérie [Algeria]' against '103...'
# Checking: 'Algérie [Algeria]' against '104...'
# Checking: 'Algérie [Algeria]' against '105...'
# Checking: 'Algérie [Algeria]' against '106...'
# Checking: 'Algérie [Algeria]' against '107...'
# Checking: 'Algérie [Algeria]' against '108...'
# Checking: 'Algérie [Algeria]' against '109...'
# Checking: 'Algérie [Algeria]' against '110...'
# Checking: 'Algérie [Algeria]' against '111...'
# Checking: 'Algérie [Algeria]' against '112...'
# Checking: 'Algérie [Algeria]' against '113...'
# Checking: 'Algérie [Algeria]' against '114...'
# Checking: 'Algérie [Algeria]' against '115...'
# Checking: 'Algérie [Algeria]' against '116...'
# Checking: 'Algérie [Algeria]' against '117...'
# Checking: 'Algérie [Algeria]' against '118...'
# Checking: 'Algérie [Algeria]' against '119...'
# Checking: 'Algérie [Algeria]' against '120...'
# Checking: 'Algérie [Algeria]' against '121...'
# Checking: 'Algérie [Algeria]' against '122...'
# Checking: 'Algérie [Algeria]' against '123...'
# Checking: 'Algérie [Algeria]' against '124...'
# Checking: 'Algérie [Algeria]' against '125...'
# Checking: 'Algérie [Algeria]' against '126...'
# Checking: 'Algérie [Algeria]' against '127...'
# Checking: 'Algérie [Algeria]' against '128...'
# Checking: 'Algérie [Algeria]' against '129...'
# Checking: 'Algérie [Algeria]' against '130...'
# Checking: 'Algérie [Algeria]' against '131...'
# Checking: 'Algérie [Algeria]' against '132...'
# Checking: 'Algérie [Algeria]' against '133...'
# Checking: 'Algérie [Algeria]' against '134...'
# Checking: 'Algérie [Algeria]' against '135...'
# Checking: 'Algérie [Algeria]' against '136...'
# Checking: 'Algérie [Algeria]' against '137...'
# Checking: 'Algérie [Algeria]' against '138...'
# Checking: 'Algérie [Algeria]' against '139...'
# Checking: 'Algérie [Algeria]' against '140...'
# Checking: 'Algérie [Algeria]' against '141...'
# Checking: 'Algérie [Algeria]' against '142...'
# Checking: 'Algérie [Algeria]' against '143...'
# Checking: 'Algérie [Algeria]' against '144...'
# Checking: 'Algérie [Algeria]' against '145...'
# Checking: 'Algérie [Algeria]' against '146...'
# Checking: 'Algérie [Algeria]' against '147...'
# Checking: 'Algérie [Algeria]' against '148...'
# Checking: 'Algérie [Algeria]' against '149...'
# Checking: 'Algérie [Algeria]' against '150...'
# Checking: 'Algérie [Algeria]' against '151...'
# Checking: 'Algérie [Algeria]' against '152...'
# Checking: 'Algérie [Algeria]' against '153...'
# Checking: 'Algérie [Algeria]' against '154...'
# Checking: 'Algérie [Algeria]' against '155...'
# Checking: 'Algérie [Algeria]' against '156...'
# Checking: 'Algérie [Algeria]' against '157...'
# Checking: 'Algérie [Algeria]' against '158...'
# Checking: 'Algérie [Algeria]' against '159...'
# Checking: 'Algérie [Algeria]' against '160...'
# Checking: 'Algérie [Algeria]' against '161...'
# Checking: 'Algérie [Algeria]' against '162...'
# Checking: 'Algérie [Algeria]' against '163...'
# Checking: 'Algérie [Algeria]' against '164...'
# Checking: 'Algérie [Algeria]' against '165...'
# Checking: 'Algérie [Algeria]' against '166...'
# Checking: 'Algérie [Algeria]' against '167...'
# Checking: 'Algérie [Algeria]' against '168...'
# Checking: 'Algérie [Algeria]' against '169...'
# Checking: 'Algérie [Algeria]' against '170...'
# Checking: 'Algérie [Algeria]' against '171...'
# Checking: 'Algérie [Algeria]' against '172...'
# Checking: 'Algérie [Algeria]' against '173...'
# Checking: 'Algérie [Algeria]' against '174...'
# Checking: 'Algérie [Algeria]' against '175...'
# Checking: 'Algérie [Algeria]' against '176...'
# Checking: 'Algérie [Algeria]' against '177...'
# Checking: 'Algérie [Algeria]' against '178...'
# Checking: 'Algérie [Algeria]' against '179...'
# Checking: 'Algérie [Algeria]' against '180...'
# Checking: 'Algérie [Algeria]' against '181...'
# Checking: 'Algérie [Algeria]' against '182...'
# Checking: 'Algérie [Algeria]' against '183...'
# Checking: 'Algérie [Algeria]' against '184...'
# Checking: 'Algérie [Algeria]' against '185...'
# Checking: 'Algérie [Algeria]' against '186...'
# Checking: 'Algérie [Algeria]' against '187...'
# Checking: 'Algérie [Algeria]' against '188...'
# Checking: 'Algérie [Algeria]' against '189...'
# Checking: 'Algérie [Algeria]' against '190...'
# Checking: 'Algérie [Algeria]' against '191...'
# Checking: 'Algérie [Algeria]' against '192...'
# Checking: 'Algérie [Algeria]' against '193...'
# Checking: 'Algérie [Algeria]' against '194...'
# Checking: 'Algérie [Algeria]' against '195...'
# Checking: 'Algérie [Algeria]' against '196...'
# Checking: 'Algérie [Algeria]' against '197...'
# Checking: 'Algérie [Algeria]' against '198...'
# Checking: 'Algérie [Algeria]' against '199...'
# Checking: 'Algérie [Algeria]' against '200...'
#
# Matching complete!
# Total records in merged dataset: 58
# Records with matches (coordinates): 0
# Records without matches: 58
# Merged dataset saved to: C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\merged_algiers_data.csv
#
# Sample of merged data:
#      place_name matched_geoname latitude longitude  population_2008
# 0    Aïn Benian                     None      None            68354
# 1      Aïn Taya                     None      None            34501
# 2   Baba Hassen                     None      None            23756
# 3   Bab El Oued                     None      None            64732
# 4   Bab Ezzouar                     None      None            96597
# 5   Bachdjerrah                     None      None            93289
# 6        Baraki                     None      None           116375
# 7    Ben Aknoun                     None      None            18838
# 8  Beni Messous                     None      None            36191
# 9     Birkhadem                     None      None            77749
#
# Final dataset summary:
# Total records: 58
# Records with coordinates: 0
# Records with 2008 population: 58

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\points.csv')

# %%
df
# Out:
#                 @id                                      name  \
# 0    node/452418787                     Cité Mokhtar Zerhouni
# 1    node/472084248                Cité Universitaire - CUB 1
# 2    node/472084262  Bab Ezzouar - Le Pont باب الزوار - الجسر
# 3    node/472084274                 Université de Bab Ezzouar
# 4    node/472084279                                Cité Rabia
# ..              ...                                       ...
# 71  node/4377305015                            Dergana Centre
# 72  node/4377305016                       Faculté Biomédicale
# 73  node/7301592854                                  Ruisseau
# 74  node/8292893940                               Ben Redouan
# 75  node/8292893942                               Ben Redouan
#
#                        name:ar          network network:wikidata operator  \
# 0              حي مختار زرهوني  ترامواي الجزائر         Q1688502   SETRAM
# 1   الإقامة الجامعية - ح ج ب 1  ترامواي الجزائر         Q1688502   SETRAM
# 2           باب الزوار - الجسر  ترامواي الجزائر         Q1688502   SETRAM
# 3             جامعة باب الزوار  ترامواي الجزائر         Q1688502   SETRAM
# 4                     حي رابية  ترامواي الجزائر         Q1688502   SETRAM
# ..                         ...              ...              ...      ...
# 71                  درڨانة وسط  ترامواي الجزائر         Q1688502   SETRAM
# 72                         NaN  ترامواي الجزائر         Q1688502   SETRAM
# 73                     الرويسو  ترامواي الجزائر         Q1688502   SETRAM
# 74                    بن رضوان  ترامواي الجزائر         Q1688502   SETRAM
# 75                    بن رضوان  ترامواي الجزائر         Q1688502   SETRAM
#
#    operator:wikidata public_transport    railway tram  ...        lat  \
# 0          Q22688489    stop_position  tram_stop  yes  ...  36.729478
# 1          Q22688489    stop_position  tram_stop  yes  ...  36.732251
# 2          Q22688489    stop_position  tram_stop  yes  ...  36.724346
# 3          Q22688489    stop_position  tram_stop  yes  ...  36.720810
# 4          Q22688489    stop_position  tram_stop  yes  ...  36.724481
# ..               ...              ...        ...  ...  ...        ...
# 71         Q22688489    stop_position  tram_stop  yes  ...  36.772017
# 72         Q22688489    stop_position  tram_stop  yes  ...  36.777736
# 73         Q22688489    stop_position  tram_stop  yes  ...  36.742919
# 74         Q22688489    stop_position  tram_stop  yes  ...  36.755438
# 75         Q22688489    stop_position  tram_stop  yes  ...  36.755410
#
#     alt_name:ft                              alt_name:ar       alt_name:fr  \
# 0           NaN                                      NaN               NaN
# 1        RUBE 1                                      NaN               NaN
# 2           NaN                                      NaN               NaN
# 3           NaN  جامعة العلوم و التكنولوجيا هواري بومدين  Université USTHB
# 4           NaN                                      NaN               NaN
# ..          ...                                      ...               ...
# 71          NaN                                      NaN               NaN
# 72          NaN                                      NaN               NaN
# 73          NaN                                    رويسو               NaN
# 74          NaN                                      NaN               NaN
# 75          NaN                                      NaN               NaN
#
#            name:fr name:de         name:en           source name:it shelter
# 0              NaN     NaN             NaN              NaN     NaN     NaN
# 1              NaN     NaN             NaN              NaN     NaN     NaN
# 2              NaN     NaN             NaN              NaN     NaN     NaN
# 3              NaN     NaN             NaN              NaN     NaN     NaN
# 4              NaN     NaN             NaN              NaN     NaN     NaN
# ..             ...     ...             ...              ...     ...     ...
# 71  Dergana Centre     NaN  Dergana Center  local knowledge     NaN     yes
# 72             NaN     NaN             NaN  local knowledge     NaN     NaN
# 73             NaN     NaN             NaN              NaN     NaN     NaN
# 74     Ben Redouan     NaN     Ben Redouan              NaN     NaN     NaN
# 75     Ben Redouan     NaN     Ben Redouan              NaN     NaN     NaN
#
# [76 rows x 21 columns]

# %%
dataset = df[['name', 'lon', 'lat']].rename(columns={'lon': 'longitude', 'lat': 'latitude'})

# %%
print(dataset.head())
# Out:
#                                        name  longitude   latitude
# 0                     Cité Mokhtar Zerhouni   3.174324  36.729478
# 1                Cité Universitaire - CUB 1   3.184065  36.732251
# 2  Bab Ezzouar - Le Pont باب الزوار - الجسر   3.184784  36.724346
# 3                 Université de Bab Ezzouar   3.179575  36.720810
# 4                                Cité Rabia   3.176970  36.724481

# %%
dataset.to_csv(r'C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\tram_points.csv', index=False)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

def scrape_algiers_population():
    """
    Scrape population data for Algiers communes from citypopulation.de
    """
    url = "https://www.citypopulation.de/en/algeria/admin/16__el_djaza%C3%AFr/"
    
    print("Fetching data from citypopulation.de...")
    
    # Send GET request with headers to avoid blocking
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        # Parse HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all tables with class 'data'
        tables = soup.find_all('table', {'class': 'data'})
        
        if not tables:
            print("Could not find any data tables on the page")
            return None
        
        # The main table with commune data is usually the largest one
        # Let's find all rows across all tables
        all_data = []
        
        for table in tables:
            # Find all rows in the table
            rows = table.find_all('tr')
            print(f"Found {len(rows)} rows in a table")
            
            # Skip header rows - we'll process each row and check if it has commune data
            for row in rows:
                # Check if this is a data row (not a header)
                cells = row.find_all(['td', 'th'])
                
                if len(cells) >= 5:  # We need at least 5 columns (name, status, native, pop1998, pop2008)
                    # Skip if this is a header row
                    if row.find('th'):
                        continue
                    
                    # Extract place name (first cell)
                    name_cell = cells[0]
                    
                    # Skip the province row (we want communes)
                    cell_text = name_cell.get_text().strip()
                    if "Province" in str(row):
                        continue
                        
                    # Get place name
                    place_name = None
                    name_link = name_cell.find('a')
                    if name_link:
                        place_name = name_link.get_text().strip()
                    else:
                        place_name = cell_text
                    
                    # Skip empty rows or header rows
                    if not place_name or place_name == "Name":
                        continue
                    
                    # Extract status (usually "Commune")
                    status = ""
                    if len(cells) > 1:
                        status = cells[1].get_text().strip()
                    
                    # Extract native name
                    native_name = ""
                    if len(cells) > 2:
                        native_name = cells[2].get_text().strip()
                    
                    # Extract population data
                    population_1998 = None
                    population_2008 = None
                    
                    # Population 1998 (usually 4th column)
                    if len(cells) > 3:
                        pop_text = cells[3].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_1998 = int(clean_number)
                    
                    # Population 2008 (usually 5th column)
                    if len(cells) > 4:
                        pop_text = cells[4].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_2008 = int(clean_number)
                    
                    # Add to our data list
                    all_data.append({
                        'place_name': place_name,
                        'status': status,
                        'native_name': native_name,
                        'population_1998': population_1998,
                        'population_2008': population_2008
                    })
        
        print(f"Successfully extracted data for {len(all_data)} places")
        
        # Create DataFrame
        df = pd.DataFrame(all_data)
        
        # Save to CSV
        csv_filename = 'algiers_population_data.csv'
        df.to_csv(csv_filename, index=False, encoding='utf-8')
        
        print(f"Data saved to {csv_filename}")
        print("\nFirst few rows of the dataset:")
        print(df.head(10))
        
        print(f"\nDataset summary:")
        print(f"Total places: {len(df)}")
        print(f"Places with 1998 data: {df['population_1998'].notna().sum()}")
        print(f"Places with 2008 data: {df['population_2008'].notna().sum()}")
        
        return df
        
    except requests.RequestException as e:
        print(f"Error fetching the webpage: {e}")
        return None
    except Exception as e:
        print(f"Error processing data: {e}")
        import traceback
        traceback.print_exc()
        return None

# Run the scraper
if __name__ == "__main__":
    df = scrape_algiers_population()
    
    if df is not None:
        print("\n" + "="*50)
        print("SCRAPING COMPLETED SUCCESSFULLY!")
        print("="*50)
        print(f"CSV file 'algiers_population_data.csv' has been created with {len(df)} records")
    else:
        print("Scraping failed. Please check the error messages above.")
# Out:
# Fetching data from citypopulation.de...
# Found 60 rows in a table
# Found 3 rows in a table
# Found 4 rows in a table
# Found 10 rows in a table
# Found 4 rows in a table
# Successfully extracted data for 58 places
# Data saved to algiers_population_data.csv
#
# First few rows of the dataset:
#      place_name   status  native_name  population_1998  population_2008
# 0    Aïn Benian  Commune  عين البنيان            52343            68354
# 1      Aïn Taya  Commune     عين طاية            29515            34501
# 2   Baba Hassen  Commune     بابا حسن            13827            23756
# 3   Bab El Oued  Commune   باب الوادي            87557            64732
# 4   Bab Ezzouar  Commune   باب الزوار            92157            96597
# 5   Bachdjerrah  Commune     باش جراح            90073            93289
# 6        Baraki  Commune        براقي            95247           116375
# 7    Ben Aknoun  Commune     بن عكنون            19404            18838
# 8  Beni Messous  Commune     بني مسوس            17490            36191
# 9     Birkhadem  Commune     بئر خادم            55084            77749
#
# Dataset summary:
# Total places: 58
# Places with 1998 data: 58
# Places with 2008 data: 58
#
# ==================================================
# SCRAPING COMPLETED SUCCESSFULLY!
# ==================================================
# CSV file 'algiers_population_data.csv' has been created with 58 records

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

def scrape_algiers_population():
    """
    Scrape population data for Algiers communes from citypopulation.de
    """
    url = "https://www.citypopulation.de/en/algeria/admin/16__el_djaza%C3%AFr/"
    
    print("Fetching data from citypopulation.de...")
    
    # Send GET request with headers to avoid blocking
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        # Parse HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all tables with class 'data'
        tables = soup.find_all('table', {'class': 'data'})
        
        if not tables:
            print("Could not find any data tables on the page")
            return None
        
        # The main table with commune data is usually the largest one
        # Let's find all rows across all tables
        all_data = []
        
        for table in tables:
            # Find all rows in the table
            rows = table.find_all('tr')
            print(f"Found {len(rows)} rows in a table")
            
            # Skip header rows - we'll process each row and check if it has commune data
            for row in rows:
                # Check if this is a data row (not a header)
                cells = row.find_all(['td', 'th'])
                
                if len(cells) >= 5:  # We need at least 5 columns (name, status, native, pop1998, pop2008)
                    # Skip if this is a header row
                    if row.find('th'):
                        continue
                    
                    # Extract place name (first cell)
                    name_cell = cells[0]
                    
                    # Skip the province row (we want communes)
                    cell_text = name_cell.get_text().strip()
                    if "Province" in str(row):
                        continue
                        
                    # Get place name
                    place_name = None
                    name_link = name_cell.find('a')
                    if name_link:
                        place_name = name_link.get_text().strip()
                    else:
                        place_name = cell_text
                    
                    # Skip empty rows or header rows
                    if not place_name or place_name == "Name":
                        continue
                    
                    # Extract status (usually "Commune")
                    status = ""
                    if len(cells) > 1:
                        status = cells[1].get_text().strip()
                    
                    # Extract native name
                    native_name = ""
                    if len(cells) > 2:
                        native_name = cells[2].get_text().strip()
                    
                    # Extract population data
                    population_1998 = None
                    population_2008 = None
                    
                    # Population 1998 (usually 4th column)
                    if len(cells) > 3:
                        pop_text = cells[3].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_1998 = int(clean_number)
                    
                    # Population 2008 (usually 5th column)
                    if len(cells) > 4:
                        pop_text = cells[4].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_2008 = int(clean_number)
                    
                    # Add to our data list
                    all_data.append({
                        'place_name': place_name,
                        'status': status,
                        'native_name': native_name,
                        'population_1998': population_1998,
                        'population_2008': population_2008
                    })
        
        print(f"Successfully extracted data for {len(all_data)} places")
        
        # Create DataFrame
        df = pd.DataFrame(all_data)
        
        # Save to CSV
        csv_filename = 'algiers_population_data.csv'
        df.to_csv(csv_filename, index=False, encoding='utf-8')
        
        print(f"Data saved to {csv_filename}")
        print("\nFirst few rows of the dataset:")
        print(df.head(10))
        
        print(f"\nDataset summary:")
        print(f"Total places: {len(df)}")
        print(f"Places with 1998 data: {df['population_1998'].notna().sum()}")
        print(f"Places with 2008 data: {df['population_2008'].notna().sum()}")
        
        return df
        
    except requests.RequestException as e:
        print(f"Error fetching the webpage: {e}")
        return None
    except Exception as e:
        print(f"Error processing data: {e}")
        import traceback
        traceback.print_exc()
        return None

# Run the scraper
if __name__ == "__main__":
    df = scrape_algiers_population()
    
    if df is not None:
        print("\n" + "="*50)
        print("SCRAPING COMPLETED SUCCESSFULLY!")
        print("="*50)
        print(f"CSV file 'algiers_population_data.csv' has been created with {len(df)} records")
    else:
        print("Scraping failed. Please check the error messages above.")
# Out:
# Fetching data from citypopulation.de...
# Found 60 rows in a table
# Found 3 rows in a table
# Found 4 rows in a table
# Found 10 rows in a table
# Found 4 rows in a table
# Successfully extracted data for 58 places
# Data saved to algiers_population_data.csv
#
# First few rows of the dataset:
#      place_name   status  native_name  population_1998  population_2008
# 0    Aïn Benian  Commune  عين البنيان            52343            68354
# 1      Aïn Taya  Commune     عين طاية            29515            34501
# 2   Baba Hassen  Commune     بابا حسن            13827            23756
# 3   Bab El Oued  Commune   باب الوادي            87557            64732
# 4   Bab Ezzouar  Commune   باب الزوار            92157            96597
# 5   Bachdjerrah  Commune     باش جراح            90073            93289
# 6        Baraki  Commune        براقي            95247           116375
# 7    Ben Aknoun  Commune     بن عكنون            19404            18838
# 8  Beni Messous  Commune     بني مسوس            17490            36191
# 9     Birkhadem  Commune     بئر خادم            55084            77749
#
# Dataset summary:
# Total places: 58
# Places with 1998 data: 58
# Places with 2008 data: 58
#
# ==================================================
# SCRAPING COMPLETED SUCCESSFULLY!
# ==================================================
# CSV file 'algiers_population_data.csv' has been created with 58 records

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

def scrape_algiers_population():
    """
    Scrape population data for Algiers communes from citypopulation.de
    """
    url = "https://www.citypopulation.de/en/algeria/admin/16__el_djaza%C3%AFr/"
    
    print("Fetching data from citypopulation.de...")
    
    # Send GET request with headers to avoid blocking
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        # Parse HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all tables with class 'data'
        tables = soup.find_all('table', {'class': 'data'})
        
        if not tables:
            print("Could not find any data tables on the page")
            return None
        
        # The main table with commune data is usually the largest one
        # Let's find all rows across all tables
        all_data = []
        
        for table in tables:
            # Find all rows in the table
            rows = table.find_all('tr')
            print(f"Found {len(rows)} rows in a table")
            
            # Skip header rows - we'll process each row and check if it has commune data
            for row in rows:
                # Check if this is a data row (not a header)
                cells = row.find_all(['td', 'th'])
                
                if len(cells) >= 5:  # We need at least 5 columns (name, status, native, pop1998, pop2008)
                    # Skip if this is a header row
                    if row.find('th'):
                        continue
                    
                    # Extract place name (first cell)
                    name_cell = cells[0]
                    
                    # Skip the province row (we want communes)
                    cell_text = name_cell.get_text().strip()
                    if "Province" in str(row):
                        continue
                        
                    # Get place name
                    place_name = None
                    name_link = name_cell.find('a')
                    if name_link:
                        place_name = name_link.get_text().strip()
                    else:
                        place_name = cell_text
                    
                    # Skip empty rows or header rows
                    if not place_name or place_name == "Name":
                        continue
                    
                    # Extract status (usually "Commune")
                    status = ""
                    if len(cells) > 1:
                        status = cells[1].get_text().strip()
                    
                    # Extract native name
                    native_name = ""
                    if len(cells) > 2:
                        native_name = cells[2].get_text().strip()
                    
                    # Extract population data
                    population_1998 = None
                    population_2008 = None
                    
                    # Population 1998 (usually 4th column)
                    if len(cells) > 3:
                        pop_text = cells[3].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_1998 = int(clean_number)
                    
                    # Population 2008 (usually 5th column)
                    if len(cells) > 4:
                        pop_text = cells[4].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_2008 = int(clean_number)
                    
                    # Add to our data list
                    all_data.append({
                        'place_name': place_name,
                        'status': status,
                        'native_name': native_name,
                        'population_1998': population_1998,
                        'population_2008': population_2008
                    })
        
        print(f"Successfully extracted data for {len(all_data)} places")
        
        # Create DataFrame
        df = pd.DataFrame(all_data)
        
        # Save to CSV
        csv_filename = 'algiers_population_data.csv'
        df.to_csv(csv_filename, index=False, encoding='utf-8')
        
        print(f"Data saved to {csv_filename}")
        print("\nFirst few rows of the dataset:")
        print(df.head(10))
        
        print(f"\nDataset summary:")
        print(f"Total places: {len(df)}")
        print(f"Places with 1998 data: {df['population_1998'].notna().sum()}")
        print(f"Places with 2008 data: {df['population_2008'].notna().sum()}")
        
        return df
        
    except requests.RequestException as e:
        print(f"Error fetching the webpage: {e}")
        return None
    except Exception as e:
        print(f"Error processing data: {e}")
        import traceback
        traceback.print_exc()
        return None

# Run the scraper
if __name__ == "__main__":
    df = scrape_algiers_population()
    
    if df is not None:
        print("\n" + "="*50)
        print("SCRAPING COMPLETED SUCCESSFULLY!")
        print("="*50)
        print(f"CSV file 'algiers_population_data.csv' has been created with {len(df)} records")
    else:
        print("Scraping failed. Please check the error messages above.")
# Out:
# Fetching data from citypopulation.de...
# Found 60 rows in a table
# Found 3 rows in a table
# Found 4 rows in a table
# Found 10 rows in a table
# Found 4 rows in a table
# Successfully extracted data for 58 places
# Data saved to algiers_population_data.csv
#
# First few rows of the dataset:
#      place_name   status  native_name  population_1998  population_2008
# 0    Aïn Benian  Commune  عين البنيان            52343            68354
# 1      Aïn Taya  Commune     عين طاية            29515            34501
# 2   Baba Hassen  Commune     بابا حسن            13827            23756
# 3   Bab El Oued  Commune   باب الوادي            87557            64732
# 4   Bab Ezzouar  Commune   باب الزوار            92157            96597
# 5   Bachdjerrah  Commune     باش جراح            90073            93289
# 6        Baraki  Commune        براقي            95247           116375
# 7    Ben Aknoun  Commune     بن عكنون            19404            18838
# 8  Beni Messous  Commune     بني مسوس            17490            36191
# 9     Birkhadem  Commune     بئر خادم            55084            77749
#
# Dataset summary:
# Total places: 58
# Places with 1998 data: 58
# Places with 2008 data: 58
#
# ==================================================
# SCRAPING COMPLETED SUCCESSFULLY!
# ==================================================
# CSV file 'algiers_population_data.csv' has been created with 58 records

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

def scrape_algiers_population():
    """
    Scrape population data for Algiers communes from citypopulation.de
    """
    url = "https://www.citypopulation.de/en/algeria/admin/16__el_djaza%C3%AFr/"
    
    print("Fetching data from citypopulation.de...")
    
    # Send GET request with headers to avoid blocking
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        # Parse HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all tables with class 'data'
        tables = soup.find_all('table', {'class': 'data'})
        
        if not tables:
            print("Could not find any data tables on the page")
            return None
        
        # The main table with commune data is usually the largest one
        # Let's find all rows across all tables
        all_data = []
        
        for table in tables:
            # Find all rows in the table
            rows = table.find_all('tr')
            print(f"Found {len(rows)} rows in a table")
            
            # Skip header rows - we'll process each row and check if it has commune data
            for row in rows:
                # Check if this is a data row (not a header)
                cells = row.find_all(['td', 'th'])
                
                if len(cells) >= 5:  # We need at least 5 columns (name, status, native, pop1998, pop2008)
                    # Skip if this is a header row
                    if row.find('th'):
                        continue
                    
                    # Extract place name (first cell)
                    name_cell = cells[0]
                    
                    # Skip the province row (we want communes)
                    cell_text = name_cell.get_text().strip()
                    if "Province" in str(row):
                        continue
                        
                    # Get place name
                    place_name = None
                    name_link = name_cell.find('a')
                    if name_link:
                        place_name = name_link.get_text().strip()
                    else:
                        place_name = cell_text
                    
                    # Skip empty rows or header rows
                    if not place_name or place_name == "Name":
                        continue
                    
                    # Extract status (usually "Commune")
                    status = ""
                    if len(cells) > 1:
                        status = cells[1].get_text().strip()
                    
                    # Extract native name
                    native_name = ""
                    if len(cells) > 2:
                        native_name = cells[2].get_text().strip()
                    
                    # Extract population data
                    population_1998 = None
                    population_2008 = None
                    
                    # Population 1998 (usually 4th column)
                    if len(cells) > 3:
                        pop_text = cells[3].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_1998 = int(clean_number)
                    
                    # Population 2008 (usually 5th column)
                    if len(cells) > 4:
                        pop_text = cells[4].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_2008 = int(clean_number)
                    
                    # Add to our data list
                    all_data.append({
                        'place_name': place_name,
                        'status': status,
                        'native_name': native_name,
                        'population_1998': population_1998,
                        'population_2008': population_2008
                    })
        
        print(f"Successfully extracted data for {len(all_data)} places")
        
        # Create DataFrame
        df = pd.DataFrame(all_data)
        
        # Save to CSV
        csv_filename = 'algiers_population_data.csv'
        df.to_csv(csv_filename, index=False, encoding='utf-8')
        
        print(f"Data saved to {csv_filename}")
        print("\nFirst few rows of the dataset:")
        print(df.head(10))
        
        print(f"\nDataset summary:")
        print(f"Total places: {len(df)}")
        print(f"Places with 1998 data: {df['population_1998'].notna().sum()}")
        print(f"Places with 2008 data: {df['population_2008'].notna().sum()}")
        
        return df
        
    except requests.RequestException as e:
        print(f"Error fetching the webpage: {e}")
        return None
    except Exception as e:
        print(f"Error processing data: {e}")
        import traceback
        traceback.print_exc()
        return None

# Run the scraper
if __name__ == "__main__":
    df = scrape_algiers_population()
    
    if df is not None:
        print("\n" + "="*50)
        print("SCRAPING COMPLETED SUCCESSFULLY!")
        print("="*50)
        print(f"CSV file 'algiers_population_data.csv' has been created with {len(df)} records")
    else:
        print("Scraping failed. Please check the error messages above.")
# Out:
# Fetching data from citypopulation.de...
# Found 60 rows in a table
# Found 3 rows in a table
# Found 4 rows in a table
# Found 10 rows in a table
# Found 4 rows in a table
# Successfully extracted data for 58 places
# Data saved to algiers_population_data.csv
#
# First few rows of the dataset:
#      place_name   status  native_name  population_1998  population_2008
# 0    Aïn Benian  Commune  عين البنيان            52343            68354
# 1      Aïn Taya  Commune     عين طاية            29515            34501
# 2   Baba Hassen  Commune     بابا حسن            13827            23756
# 3   Bab El Oued  Commune   باب الوادي            87557            64732
# 4   Bab Ezzouar  Commune   باب الزوار            92157            96597
# 5   Bachdjerrah  Commune     باش جراح            90073            93289
# 6        Baraki  Commune        براقي            95247           116375
# 7    Ben Aknoun  Commune     بن عكنون            19404            18838
# 8  Beni Messous  Commune     بني مسوس            17490            36191
# 9     Birkhadem  Commune     بئر خادم            55084            77749
#
# Dataset summary:
# Total places: 58
# Places with 1998 data: 58
# Places with 2008 data: 58
#
# ==================================================
# SCRAPING COMPLETED SUCCESSFULLY!
# ==================================================
# CSV file 'algiers_population_data.csv' has been created with 58 records

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

def scrape_algiers_population():
    """
    Scrape population data for Algiers communes from citypopulation.de
    """
    url = "https://www.citypopulation.de/en/algeria/admin/16__el_djaza%C3%AFr/"
    
    print("Fetching data from citypopulation.de...")
    
    # Send GET request with headers to avoid blocking
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        # Parse HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all tables with class 'data'
        tables = soup.find_all('table', {'class': 'data'})
        
        if not tables:
            print("Could not find any data tables on the page")
            return None
        
        # The main table with commune data is usually the largest one
        # Let's find all rows across all tables
        all_data = []
        
        for table in tables:
            # Find all rows in the table
            rows = table.find_all('tr')
            print(f"Found {len(rows)} rows in a table")
            
            # Skip header rows - we'll process each row and check if it has commune data
            for row in rows:
                # Check if this is a data row (not a header)
                cells = row.find_all(['td', 'th'])
                
                if len(cells) >= 5:  # We need at least 5 columns (name, status, native, pop1998, pop2008)
                    # Skip if this is a header row
                    if row.find('th'):
                        continue
                    
                    # Extract place name (first cell)
                    name_cell = cells[0]
                    
                    # Skip the province row (we want communes)
                    cell_text = name_cell.get_text().strip()
                    if "Province" in str(row):
                        continue
                        
                    # Get place name
                    place_name = None
                    name_link = name_cell.find('a')
                    if name_link:
                        place_name = name_link.get_text().strip()
                    else:
                        place_name = cell_text
                    
                    # Skip empty rows or header rows
                    if not place_name or place_name == "Name":
                        continue
                    
                    # Extract status (usually "Commune")
                    status = ""
                    if len(cells) > 1:
                        status = cells[1].get_text().strip()
                    
                    # Extract native name
                    native_name = ""
                    if len(cells) > 2:
                        native_name = cells[2].get_text().strip()
                    
                    # Extract population data
                    population_1998 = None
                    population_2008 = None
                    
                    # Population 1998 (usually 4th column)
                    if len(cells) > 3:
                        pop_text = cells[3].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_1998 = int(clean_number)
                    
                    # Population 2008 (usually 5th column)
                    if len(cells) > 4:
                        pop_text = cells[4].get_text().strip()
                        numbers = re.findall(r'[\d,]+', pop_text)
                        if numbers:
                            clean_number = numbers[0].replace(',', '')
                            if clean_number.isdigit():
                                population_2008 = int(clean_number)
                    
                    # Add to our data list
                    all_data.append({
                        'place_name': place_name,
                        'status': status,
                        'native_name': native_name,
                        'population_1998': population_1998,
                        'population_2008': population_2008
                    })
        
        print(f"Successfully extracted data for {len(all_data)} places")
        
        # Create DataFrame
        df = pd.DataFrame(all_data)
        
        # Save to CSV
        csv_filename = 'algiers_population_data.csv'
        df.to_csv(csv_filename, index=False, encoding='utf-8')
        
        print(f"Data saved to {csv_filename}")
        print("\nFirst few rows of the dataset:")
        print(df.head(10))
        
        print(f"\nDataset summary:")
        print(f"Total places: {len(df)}")
        print(f"Places with 1998 data: {df['population_1998'].notna().sum()}")
        print(f"Places with 2008 data: {df['population_2008'].notna().sum()}")
        
        return df
        
    except requests.RequestException as e:
        print(f"Error fetching the webpage: {e}")
        return None
    except Exception as e:
        print(f"Error processing data: {e}")
        import traceback
        traceback.print_exc()
        return None

# Run the scraper
if __name__ == "__main__":
    df = scrape_algiers_population()
    
    if df is not None:
        print("\n" + "="*50)
        print("SCRAPING COMPLETED SUCCESSFULLY!")
        print("="*50)
        print(f"CSV file 'algiers_population_data.csv' has been created with {len(df)} records")
    else:
        print("Scraping failed. Please check the error messages above.")
# Out:
# Fetching data from citypopulation.de...
# Found 60 rows in a table
# Found 3 rows in a table
# Found 4 rows in a table
# Found 10 rows in a table
# Found 4 rows in a table
# Successfully extracted data for 58 places
# Data saved to algiers_population_data.csv
#
# First few rows of the dataset:
#      place_name   status  native_name  population_1998  population_2008
# 0    Aïn Benian  Commune  عين البنيان            52343            68354
# 1      Aïn Taya  Commune     عين طاية            29515            34501
# 2   Baba Hassen  Commune     بابا حسن            13827            23756
# 3   Bab El Oued  Commune   باب الوادي            87557            64732
# 4   Bab Ezzouar  Commune   باب الزوار            92157            96597
# 5   Bachdjerrah  Commune     باش جراح            90073            93289
# 6        Baraki  Commune        براقي            95247           116375
# 7    Ben Aknoun  Commune     بن عكنون            19404            18838
# 8  Beni Messous  Commune     بني مسوس            17490            36191
# 9     Birkhadem  Commune     بئر خادم            55084            77749
#
# Dataset summary:
# Total places: 58
# Places with 1998 data: 58
# Places with 2008 data: 58
#
# ==================================================
# SCRAPING COMPLETED SUCCESSFULLY!
# ==================================================
# CSV file 'algiers_population_data.csv' has been created with 58 records

# %%
final = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\clean\final_population_and_credentials_dataset.csv")
final.head()
# Out:
#   commune_name  population        Latitude      Longitude
# 0   Ain Benian       68354  N 36° 48′ 10''  E 2° 55′ 18''
# 1     Ain Taya       34501  N 36° 47′ 36''  E 3° 17′ 13''
# 2  Baba Hassen       23756  N 36° 41′ 44''  E 2° 58′ 21''
# 3  Bab El Oued       64732  N 36° 47′ 53''   E 3° 1′ 27''
# 4  Bab Ezzouar       96597  N 36° 43′ 34''  E 3° 10′ 58''

# %%
import pandas as pd
import re

def dms_to_decimal(dms_string):
    """
    Convert degrees, minutes, seconds to decimal degrees
    Example: "N 36° 48′ 10''" -> 36.8027777778
    """
    # Extract direction (N/S/E/W)
    direction = dms_string.strip()[0]
    
    # Extract numbers using regex
    numbers = re.findall(r'\d+', dms_string)
    
    if len(numbers) != 3:
        return None
    
    degrees = int(numbers[0])
    minutes = int(numbers[1])
    seconds = int(numbers[2])
    
    # Convert to decimal
    decimal = degrees + minutes/60 + seconds/3600
    
    # Apply direction (negative for South and West)
    if direction in ['S', 'W']:
        decimal = -decimal
    
    return decimal

# Read the dataset
final = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\clean\final_population_and_credentials_dataset.csv")

# Convert coordinates
final['Latitude_Decimal'] = final['Latitude'].apply(dms_to_decimal)
final['Longitude_Decimal'] = final['Longitude'].apply(dms_to_decimal)

# Reorder columns to match your desired format
final_converted = final[['commune_name', 'Longitude_Decimal', 'Latitude_Decimal', 'population']].copy()

# Rename columns to match your example
final_converted.columns = ['commune_name', 'longitude', 'latitude', 'population']

# Display the converted data
print("Original format:")
print(final[['commune_name', 'population', 'Latitude', 'Longitude']].head())
print("\nConverted format:")
print(final_converted.head())

# Save the converted dataset
output_path = r"C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\clean\final_population_and_credentials_dataset_converted.csv"
final_converted.to_csv(output_path, index=False)
print(f"\nConverted dataset saved to: {output_path}")

# Verify conversion with first row as example
first_row = final.iloc[0]
print(f"\nVerification - First row conversion:")
print(f"Original: {first_row['commune_name']} - Lat: {first_row['Latitude']}, Lon: {first_row['Longitude']}")
print(f"Converted: {final_converted.iloc[0]['commune_name']} - Lat: {final_converted.iloc[0]['latitude']}, Lon: {final_converted.iloc[0]['longitude']}")
# Out:
# Original format:
#   commune_name  population        Latitude      Longitude
# 0   Ain Benian       68354  N 36° 48′ 10''  E 2° 55′ 18''
# 1     Ain Taya       34501  N 36° 47′ 36''  E 3° 17′ 13''
# 2  Baba Hassen       23756  N 36° 41′ 44''  E 2° 58′ 21''
# 3  Bab El Oued       64732  N 36° 47′ 53''   E 3° 1′ 27''
# 4  Bab Ezzouar       96597  N 36° 43′ 34''  E 3° 10′ 58''
#
# Converted format:
#   commune_name  longitude   latitude  population
# 0   Ain Benian   2.921667  36.802778       68354
# 1     Ain Taya   3.286944  36.793333       34501
# 2  Baba Hassen   2.972500  36.695556       23756
# 3  Bab El Oued   3.024167  36.798056       64732
# 4  Bab Ezzouar   3.182778  36.726111       96597
#
# Converted dataset saved to: C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\clean\final_population_and_credentials_dataset_converted.csv
#
# Verification - First row conversion:
# Original: Ain Benian - Lat: N 36° 48′ 10'', Lon: E 2° 55′ 18''
# Converted: Ain Benian - Lat: 36.80277777777778, Lon: 2.9216666666666664

# %%
finall = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\study_points.csv")
finall.head()
# Out:
#               @id                                      name  \
# 0  node/452418787                     Cité Mokhtar Zerhouni
# 1  node/472084248                Cité Universitaire - CUB 1
# 2  node/472084262  Bab Ezzouar - Le Pont باب الزوار - الجسر
# 3  node/472084274                 Université de Bab Ezzouar
# 4  node/472084279                                Cité Rabia
#
#                       name:ar          network network:wikidata operator  \
# 0             حي مختار زرهوني  ترامواي الجزائر         Q1688502   SETRAM
# 1  الإقامة الجامعية - ح ج ب 1  ترامواي الجزائر         Q1688502   SETRAM
# 2          باب الزوار - الجسر  ترامواي الجزائر         Q1688502   SETRAM
# 3            جامعة باب الزوار  ترامواي الجزائر         Q1688502   SETRAM
# 4                    حي رابية  ترامواي الجزائر         Q1688502   SETRAM
#
#   operator:wikidata public_transport    railway tram  ...  old_short_name  \
# 0         Q22688489    stop_position  tram_stop  yes  ...             NaN
# 1         Q22688489    stop_position  tram_stop  yes  ...             NaN
# 2         Q22688489    stop_position  tram_stop  yes  ...             NaN
# 3         Q22688489    stop_position  tram_stop  yes  ...             NaN
# 4         Q22688489    stop_position  tram_stop  yes  ...             NaN
#
#    addr:city:ar name:es facebook alt_name:en contact:email contact:website  \
# 0           NaN     NaN      NaN         NaN           NaN             NaN
# 1           NaN     NaN      NaN         NaN           NaN             NaN
# 2           NaN     NaN      NaN         NaN           NaN             NaN
# 3           NaN     NaN      NaN         NaN           NaN             NaN
# 4           NaN     NaN      NaN         NaN           NaN             NaN
#
#   material name:fa short_name:fr
# 0      NaN     NaN           NaN
# 1      NaN     NaN           NaN
# 2      NaN     NaN           NaN
# 3      NaN     NaN           NaN
# 4      NaN     NaN           NaN
#
# [5 rows x 76 columns]

# %%
import pandas as pd

# Load your CSV
finall = pd.read_csv(r"C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\study_points.csv")

# Keep only the desired columns
cleaned = finall[['name', 'lon', 'lat']].dropna()

cleaned.rename(columns={'name': 'commune_name', 'lon': 'longitude', 'lat': 'latitude'}, inplace=True)

# Save cleaned data to a new file (optional)
cleaned.to_csv(r"C:\Users\user\OneDrive\Desktop\ibtikar_backend-main\Genetic_Algo\clean\cleaned_study_points.csv", index=False)

# Preview
print(cleaned.head())
# Out:
#                                commune_name  longitude   latitude
# 0                     Cité Mokhtar Zerhouni   3.174324  36.729478
# 1                Cité Universitaire - CUB 1   3.184065  36.732251
# 2  Bab Ezzouar - Le Pont باب الزوار - الجسر   3.184784  36.724346
# 3                 Université de Bab Ezzouar   3.179575  36.720810
# 4                                Cité Rabia   3.176970  36.724481
